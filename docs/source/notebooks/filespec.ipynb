# %% [markdown]
# # Coffea Dataset Tools: FileSpec Classes Tutorial
#
# This notebook provides a comprehensive guide to using the new Pydantic-based FileSpec classes in Coffea's dataset tools. These classes provide type-safe, validated data structures for managing file specifications, datasets, and filesets in high-energy physics data analysis workflows.
#
# ## Overview
#
# The FileSpec system provides:
# - **Type-safe data structures** with automatic validation
# - **Automatic format detection** for ROOT and Parquet files
# - **Seamless integration** with existing Coffea functions
# - **JSON serialization/deserialization** for data persistence
# - **Automatic promotion** between optional and concrete specifications
#
# ## Table of Contents
#
# 1. [Basic File Specifications](#basic-file-specifications)
# 2. [InputFiles, PreprocessedFiles](#coffea-file-dict)
# 3. [Dataset Specifications](#dataset-specifications)
# 4. [Fileset Specifications](#fileset-specifications)
# 5. [Integration with Preprocessing](#integration-with-preprocessing)
# 6. [Integration with apply_to_fileset](#integration-with-apply_to_fileset)
# 7. [Dataset Manipulation Functions](#dataset-manipulation-functions)
# 8. [Advanced Usage Examples](#advanced-usage-examples)
# 9. [Migration from Legacy Formats](#migration-from-legacy-formats)

# %%
# Import necessary libraries
from pydantic import ValidationError
import rich
import dask


# Import the FileSpec classes and dataset tools
from coffea.dataset_tools import (
    # FileSpec classes
    ROOTFileSpec,
    ParquetFileSpec,
    CoffeaROOTFileSpec,
    CoffeaROOTFileSpecOptional,
    CoffeaParquetFileSpec,
    CoffeaParquetFileSpecOptional,
    InputFiles,
    DatasetSpec,
    FilesetSpec,
    
    # Dataset manipulation functions
    preprocess,
    apply_to_fileset,
    max_chunks,
    max_chunks_per_file,
    slice_chunks,
    slice_files,
    max_files,
    filter_files,

    # ModelFactory utility class
    ModelFactory,
)
from coffea.nanoevents import NanoAODSchema
from coffea.processor.test_items import NanoEventsProcessor

print("FileSpec classes and dataset tools imported successfully!")
# Out:
# FileSpec classes and dataset tools imported successfully!

# %% [markdown]
# ## 1. Basic File Specifications
#
# The FileSpec system provides several classes for representing individual file specifications:
#
# ### File Specification Hierarchy
#
# - **ROOTFileSpec**: Basic specification for ROOT files
# - **ParquetFileSpec**: Basic specification for Parquet files
# - **CoffeaROOTFileSpecOptional**: ROOT files with optional metadata
# - **CoffeaROOTFileSpec**: ROOT files with complete metadata (required)
# - **CoffeaParquetFileSpecOptional**: Parquet files with optional metadata
# - **CoffeaParquetFileSpec**: Parquet files with complete metadata (required)

# %%
# 1.1 Basic ROOTFileSpec for ROOT files
print("=== Basic ROOTFileSpec ===")

# Minimal ROOT file specification
uproot_spec = ROOTFileSpec(object_path="Events")
print("Basic ROOT spec:")
rich.print(uproot_spec)
print(f"Format: {uproot_spec.format}")
print(f"Steps: {uproot_spec.steps}")

# ROOT file specification with steps
uproot_spec_with_steps = ROOTFileSpec(
    object_path="Events",
    steps=[[0, 1000], [1000, 2000], [2000, 3000]]
)
print("\nROOT spec with steps:")
rich.print(uproot_spec_with_steps)
# Out:
# === Basic ROOTFileSpec ===
# Basic ROOT spec:
# ROOTFileSpec(object_path='Events', steps=None, num_entries=None, format='root', num_selected_entries=None)
# Format: root
# Steps: None
#
# ROOT spec with steps:
# ROOTFileSpec(
#     object_path='Events',
#     steps=[[0, 1000], [1000, 2000], [2000, 3000]],
#     num_entries=None,
#     format='root',
#     num_selected_entries=3000
# )

# %%
# 1.2 Basic ParquetFileSpec for Parquet files
print("=== Basic ParquetFileSpec ===")

# Minimal Parquet file specification
parquet_spec = ParquetFileSpec()
print("Basic Parquet spec:")
rich.print(parquet_spec)
print(f"Format: {parquet_spec.format}")
print(f"Object path (always None): {parquet_spec.object_path}")

# Parquet file specification with steps
parquet_spec_with_steps = ParquetFileSpec(
    steps=[[0, 5000], [5000, 10000]]
)
print("\nParquet spec with steps:")
rich.print(parquet_spec_with_steps)
# Out:
# === Basic ParquetFileSpec ===
# Basic Parquet spec:
# ParquetFileSpec(object_path=None, steps=None, num_entries=None, format='parquet', num_selected_entries=None)
# Format: parquet
# Object path (always None): None
#
# Parquet spec with steps:
# ParquetFileSpec(
#     object_path=None,
#     steps=[[0, 5000], [5000, 10000]],
#     num_entries=None,
#     format='parquet',
#     num_selected_entries=10000
# )

# %%
# 1.3 CoffeaROOTFileSpecOptional - ROOT files with optional metadata
print("=== CoffeaROOTFileSpecOptional ===")

# Optional specification with minimal data
coffea_uproot_optional = CoffeaROOTFileSpecOptional(object_path="Events")
print("Optional ROOT spec:")
rich.print(coffea_uproot_optional)

# Optional specification with some metadata
coffea_uproot_partial = CoffeaROOTFileSpecOptional(
    object_path="Events",
    steps=[[0, 1000]],
    num_entries=1000
)
print("Partial ROOT spec:")
rich.print(coffea_uproot_partial)

# Optional specification with all metadata
coffea_uproot_complete = CoffeaROOTFileSpecOptional(
    object_path="Events",
    steps=[[0, 1000], [1000, 2000]],
    num_entries=2000,
    uuid="12345678-90ab-cdef-1234-567890abcdef"
)
print("Complete optional ROOT spec:")
rich.print(coffea_uproot_complete)
# Out:
# === CoffeaROOTFileSpecOptional ===
# Optional ROOT spec:
# CoffeaROOTFileSpecOptional(
#     object_path='Events',
#     steps=None,
#     num_entries=None,
#     format='root',
#     uuid=None,
#     num_selected_entries=None
# )
# Partial ROOT spec:
# CoffeaROOTFileSpecOptional(
#     object_path='Events',
#     steps=[[0, 1000]],
#     num_entries=1000,
#     format='root',
#     uuid=None,
#     num_selected_entries=1000
# )
# Complete optional ROOT spec:
# CoffeaROOTFileSpecOptional(
#     object_path='Events',
#     steps=[[0, 1000], [1000, 2000]],
#     num_entries=2000,
#     format='root',
#     uuid='12345678-90ab-cdef-1234-567890abcdef',
#     num_selected_entries=2000
# )

# %%
# 1.4 CoffeaROOTFileSpec - ROOT files with required metadata
print("=== CoffeaROOTFileSpec ===")

# Complete specification (all fields required)
try:
    coffea_uproot_required = CoffeaROOTFileSpec(
        object_path="Events",
        steps=[[0, 1000], [1000, 2000]],
        num_entries=2000,
        uuid="12345678-90ab-cdef-1234-567890abcdef"
    )
    print("Complete required ROOT spec:")
    rich.print(coffea_uproot_required)
except ValidationError as e:
    print(f"Validation error: {e}")

# Attempt to create incomplete specification (should fail)
try:
    incomplete_spec = CoffeaROOTFileSpec(object_path="Events")
    print("This shouldn't print - validation should fail!")
except ValidationError as e:
    print(f"Expected validation error for incomplete spec: {e.error_count()} errors")
    rich.print(e)
# Out:
# === CoffeaROOTFileSpec ===
# Complete required ROOT spec:
# CoffeaROOTFileSpec(
#     object_path='Events',
#     steps=[[0, 1000], [1000, 2000]],
#     num_entries=2000,
#     format='root',
#     uuid='12345678-90ab-cdef-1234-567890abcdef',
#     num_selected_entries=2000
# )
# Expected validation error for incomplete spec: 3 errors
# 3 validation errors for CoffeaROOTFileSpec
# steps
#   Field required [type=missing, input_value={'object_path': 'Events'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# num_entries
#   Field required [type=missing, input_value={'object_path': 'Events'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# uuid
#   Field required [type=missing, input_value={'object_path': 'Events'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing

# %%
# 1.5 Parquet specifications (similar pattern)
print("=== CoffeaParquetFileSpec ===")

# Optional Parquet specification
parquet_optional = CoffeaParquetFileSpecOptional(
    steps=[[0, 5000]],
    num_entries=5000,
    uuid="parquet-uuid-example"
)
print("Optional Parquet spec:")
rich.print(parquet_optional)

# Required Parquet specification
parquet_required = CoffeaParquetFileSpec(
    steps=[[0, 5000], [5000, 10000]],
    num_entries=10000,
    uuid="parquet-uuid-complete"
)
print("Required Parquet spec:")
rich.print(parquet_required)
# Out:
# === CoffeaParquetFileSpec ===
# Optional Parquet spec:
# CoffeaParquetFileSpecOptional(
#     object_path=None,
#     steps=[[0, 5000]],
#     num_entries=5000,
#     format='parquet',
#     uuid='parquet-uuid-example',
#     num_selected_entries=5000
# )
# Required Parquet spec:
# CoffeaParquetFileSpec(
#     object_path=None,
#     steps=[[0, 5000], [5000, 10000]],
#     num_entries=10000,
#     format='parquet',
#     uuid='parquet-uuid-complete',
#     num_selected_entries=10000
# )

# %% [markdown]
# ## 2. InputFiles Specification
#
# The `InputFiles` classe is a dictionary-like containers for any mixture of CoffeaFileSpec classes, both Uproot/Parquet and concrete/Optional. `PreprocessedFiles` is the specific subtype permitting only concrete FileSpecs. They automatically handle:
#
# - **Format detection**: Automatically identifies if files are ROOT or Parquet, by testing the key (filename)
# - **Dictionary-like interface**: Easy access to files using standard dict methods
# - **FileSpec promotion**: Automatically tries to upcast CoffeaROOTFileSpecOptional and CoffeaParquetFileSpecOptional to their concrete classes, when the necessary fields have been set post-initialization (such as when they are preprocessed)
# - **FileSpec-wide format**: Provides the `format` computed property to determine which format(s) are present.
#
# The `InputFiles` or `PreprocessedFiles` forms the "files" subfield of the `DatasetSpec` class. Notably, unlike the FileSpec classes, it doesn't require kwarg-setting in the constructor, simply pass in a regular dictionary of `{"filename1": dict|FileSpec, ..., "filenameN": dict|FileSpec}`

# %%
# 2.1 Create an InputFiles
print("=== InputFiles ===")

# using a dictioanry of CoffeaROOTFileSpec(Optional) and CoffeaParquetFileSpec(Optional)
dict_of_filespecs = {
    "file1.root": CoffeaROOTFileSpec(
        object_path="Events", steps=[[0, 10]], num_entries=10, uuid="uuid1"
    ),
    "file1.parquet": CoffeaParquetFileSpec(
        steps=[[0, 100]], num_entries=100, uuid="uuid2"
    ),
    "file2.root": CoffeaROOTFileSpecOptional(
        object_path="Events", steps=[[10, 20]], num_entries=None, uuid=None
    ),
}

filedict_from_filespecs = InputFiles(dict_of_filespecs)

print("InputFiles:")
rich.print(filedict_from_filespecs)

# computed property: format
print(f"Detected format(s): {filedict_from_filespecs.format}")
print(f"Number of files: {len(filedict_from_filespecs)}")

# Iteration over the file dict
print("Iterating over file dict:")
for fname, spec in filedict_from_filespecs.items():
    print(f"File: {fname}\nSpec:")
    rich.print(spec)
    
# __getitem__, __setitem__ access
print(f"Accessing 'file1.root': {filedict_from_filespecs['file1.root']}")

print("=== Modifying a file spec in the dict ===")
filedict_from_filespecs["file2.root"].num_entries = 20

filedict_from_filespecs["file3.root"] = CoffeaROOTFileSpec(
    object_path="Events", steps=[[0, 30]], num_entries=30, uuid="uuid3"
)

# show keys
print(f"Keys in filedict: {list(filedict_from_filespecs.keys())}")
# Out:
# === InputFiles ===
# InputFiles:
# InputFiles(
#     root={
#         'file1.root': CoffeaROOTFileSpec(
#             object_path='Events',
#             steps=[[0, 10]],
#             num_entries=10,
#             format='root',
#             uuid='uuid1',
#             num_selected_entries=10
#         ),
#         'file1.parquet': CoffeaParquetFileSpec(
#             object_path=None,
#             steps=[[0, 100]],
#             num_entries=100,
#             format='parquet',
#             uuid='uuid2',
#             num_selected_entries=100
#         ),
#         'file2.root': CoffeaROOTFileSpecOptional(
#             object_path='Events',
#             steps=[[10, 20]],
#             num_entries=None,
#             format='root',
#             uuid=None,
#             num_selected_entries=10
#         )
#     }
# )
# Detected format(s): root|parquet
# Number of files: 3
# Iterating over file dict:
# File: file1.root
# Spec:
# CoffeaROOTFileSpec(
#     object_path='Events',
#     steps=[[0, 10]],
#     num_entries=10,
#     format='root',
#     uuid='uuid1',
#     num_selected_entries=10
# )
# File: file1.parquet
# Spec:
# CoffeaParquetFileSpec(
#     object_path=None,
#     steps=[[0, 100]],
#     num_entries=100,
#     format='parquet',
#     uuid='uuid2',
#     num_selected_entries=100
# )
# File: file2.root
# Spec:
# CoffeaROOTFileSpecOptional(
#     object_path='Events',
#     steps=[[10, 20]],
#     num_entries=None,
#     format='root',
#     uuid=None,
#     num_selected_entries=10
# )
# Accessing 'file1.root': object_path='Events' steps=[[0, 10]] num_entries=10 format='root' uuid='uuid1' num_selected_entries=10
# === Modifying a file spec in the dict ===
# Keys in filedict: ['file1.root', 'file1.parquet', 'file2.root', 'file3.root']

# %%
# 2.2 Create a InputFiles from pure dictionary
print("=== InputFiles from pure dictionary ===")

dict_of_dicts = {
    "file1.root": {
        "object_path": "Events", 
        "steps": [[0, 10]], 
        "num_entries": 10, 
        "uuid": "uuid1"
    },
    "file1.parquet": {
        "steps": [[0, 100]], 
        "num_entries": 100, 
        "uuid": "uuid2"
    },
    "file2.root": {
        "object_path": "Events", 
        "steps": [[10, 20]], 
        "num_entries": None, 
        "uuid": None
    },

}

filedict_from_pure_dict = InputFiles(dict_of_dicts)
print("InputFiles from pure dictionary:")
rich.print(filedict_from_pure_dict)
# Out:
# === InputFiles from pure dictionary ===
# InputFiles from pure dictionary:
# InputFiles(
#     root={
#         'file1.root': CoffeaROOTFileSpec(
#             object_path='Events',
#             steps=[[0, 10]],
#             num_entries=10,
#             format='root',
#             uuid='uuid1',
#             num_selected_entries=10
#         ),
#         'file1.parquet': CoffeaParquetFileSpec(
#             object_path=None,
#             steps=[[0, 100]],
#             num_entries=100,
#             format='parquet',
#             uuid='uuid2',
#             num_selected_entries=100
#         ),
#         'file2.root': CoffeaROOTFileSpecOptional(
#             object_path='Events',
#             steps=[[10, 20]],
#             num_entries=None,
#             format='root',
#             uuid=None,
#             num_selected_entries=10
#         )
#     }
# )

# %% [markdown]
# ## 3. Dataset Specifications
#
# The `DatasetSpec` class represents a collection of files that form a logical dataset. It automatically handles:
#
# - **Format detection**: Automatically identifies if files are ROOT or Parquet
# - **File validation**: Ensures all files in a dataset are compatible
# - **Metadata management**: Stores dataset-level metadata and forms
# - **Dictionary-like interface**: Easy access to files using standard dict methods

# %%
# 3.1 Creating DatasetSpec from file dictionaries
print("=== DatasetSpec Creation ===")

# Create a dataset from a simple file dictionary (ROOT files)
root_dataset_simple = DatasetSpec(
    files={
        "data_file_1.root": "Events",
        "data_file_2.root": "Events",
        "data_file_3.root": "Events"
    },
    metadata={"sample_type": "data", "year": 2023}
)

print("Simple ROOT dataset:")
rich.print(root_dataset_simple)
print(f"Detected format: {root_dataset_simple.format}")
print(f"Number of files: {len(root_dataset_simple.files)}")
print(f"Metadata: {root_dataset_simple.metadata}")
# Out:
# === DatasetSpec Creation ===
# Simple ROOT dataset:
# DatasetSpec(
#     files=InputFiles(
#         root={
#             'data_file_1.root': CoffeaROOTFileSpecOptional(
#                 object_path='Events',
#                 steps=None,
#                 num_entries=None,
#                 format='root',
#                 uuid=None,
#                 num_selected_entries=None
#             ),
#             'data_file_2.root': CoffeaROOTFileSpecOptional(
#                 object_path='Events',
#                 steps=None,
#                 num_entries=None,
#                 format='root',
#                 uuid=None,
#                 num_selected_entries=None
#             ),
#             'data_file_3.root': CoffeaROOTFileSpecOptional(
#                 object_path='Events',
#                 steps=None,
#                 num_entries=None,
#                 format='root',
#                 uuid=None,
#                 num_selected_entries=None
#             )
#         }
#     ),
#     metadata={'sample_type': 'data', 'year': 2023},
#     format='root',
#     compressed_form=None,
#     form=None
# )
# Detected format: root
# Number of files: 3
# Metadata: {'sample_type': 'data', 'year': 2023}

# %%
# 3.2 Creating DatasetSpec with complete file specifications
print("=== DatasetSpec with Complete Specifications ===")

# Create individual file specifications
file1_spec = CoffeaROOTFileSpec(
    object_path="Events",
    steps=[[0, 1000], [1000, 2000]],
    num_entries=2000,
    uuid="file1-uuid"
)

file2_spec = CoffeaROOTFileSpec(
    object_path="Events", 
    steps=[[0, 1500], [1500, 3000]],
    num_entries=3000,
    uuid="file2-uuid"
)

# Create dataset with complete specifications
complete_dataset = DatasetSpec(
    files=InputFiles({
        "processed_data_1.root": file1_spec,
        "processed_data_2.root": file2_spec
    }),
    metadata={"processing_version": "v2.1", "cross_section": 1.23},
)

print("Complete dataset:")
rich.print(complete_dataset)
print(f"Detected format: {complete_dataset.format}")
print(f"Number of files: {len(complete_dataset.files)}")
print(f"Ready for column-joining: {complete_dataset.joinable()}")
# Out:
# === DatasetSpec with Complete Specifications ===
# Complete dataset:
# DatasetSpec(
#     files=InputFiles(
#         root={
#             'processed_data_1.root': CoffeaROOTFileSpec(
#                 object_path='Events',
#                 steps=[[0, 1000], [1000, 2000]],
#                 num_entries=2000,
#                 format='root',
#                 uuid='file1-uuid',
#                 num_selected_entries=2000
#             ),
#             'processed_data_2.root': CoffeaROOTFileSpec(
#                 object_path='Events',
#                 steps=[[0, 1500], [1500, 3000]],
#                 num_entries=3000,
#                 format='root',
#                 uuid='file2-uuid',
#                 num_selected_entries=3000
#             )
#         }
#     ),
#     metadata={'processing_version': 'v2.1', 'cross_section': 1.23},
#     format='root',
#     compressed_form=None,
#     form=None
# )
# Detected format: root
# Number of files: 2
# Ready for column-joining: None

# %%
# 3.3 Mixed format handling
print("=== Mixed Format Datasets ===")

# Create a dataset with both ROOT and Parquet files
mixed_dataset = DatasetSpec(
    files={
        "data.root": CoffeaROOTFileSpec(
            object_path="Events",
            steps=[[0, 1000]],
            num_entries=1000,
            uuid="root-uuid"
        ),
        "data.parquet": CoffeaParquetFileSpec(
            steps=[[0, 2000]],
            num_entries=2000,
            uuid="parquet-uuid"
        )
    }
)

print("Mixed format dataset:")
rich.print(mixed_dataset)
print(f"Detected format: {mixed_dataset.format}")
# Out:
# === Mixed Format Datasets ===
# Mixed format dataset:
# DatasetSpec(
#     files=InputFiles(
#         root={
#             'data.root': CoffeaROOTFileSpec(
#                 object_path='Events',
#                 steps=[[0, 1000]],
#                 num_entries=1000,
#                 format='root',
#                 uuid='root-uuid',
#                 num_selected_entries=1000
#             ),
#             'data.parquet': CoffeaParquetFileSpec(
#                 object_path=None,
#                 steps=[[0, 2000]],
#                 num_entries=2000,
#                 format='parquet',
#                 uuid='parquet-uuid',
#                 num_selected_entries=2000
#             )
#         }
#     ),
#     metadata={},
#     format='root|parquet',
#     compressed_form=None,
#     form=None
# )
# Detected format: root|parquet

# %%
# 3.4 DatasetSpec from file lists
print("=== DatasetSpec from File Lists ===")

# Create dataset from a list of file:object_path strings
dataset_from_list = DatasetSpec(
    files=[
        "simulation_1.root:Events",
        "simulation_2.root:Events", 
        "root://simulation_3.root:Events",
        "simulation_4.root.1:AuxiliaryData",
    ],
    metadata={"sample_type": "simulation", "process": "ttbar"}
)

print("Dataset from list:")
rich.print(dataset_from_list)
print(f"Files: {list(dataset_from_list.files.keys())}")
# Out:
# === DatasetSpec from File Lists ===
# Dataset from list:
# DatasetSpec(
#     files=InputFiles(
#         root={
#             'simulation_1.root': CoffeaROOTFileSpecOptional(
#                 object_path='Events',
#                 steps=None,
#                 num_entries=None,
#                 format='root',
#                 uuid=None,
#                 num_selected_entries=None
#             ),
#             'simulation_2.root': CoffeaROOTFileSpecOptional(
#                 object_path='Events',
#                 steps=None,
#                 num_entries=None,
#                 format='root',
#                 uuid=None,
#                 num_selected_entries=None
#             ),
#             'root://simulation_3.root': CoffeaROOTFileSpecOptional(
#                 object_path='Events',
#                 steps=None,
#                 num_entries=None,
#                 format='root',
#                 uuid=None,
#                 num_selected_entries=None
#             ),
#             'simulation_4.root.1': CoffeaROOTFileSpecOptional(
#                 object_path='AuxiliaryData',
#                 steps=None,
#                 num_entries=None,
#                 format='root',
#                 uuid=None,
#                 num_selected_entries=None
#             )
#         }
#     ),
#     metadata={'sample_type': 'simulation', 'process': 'ttbar'},
#     format='root',
#     compressed_form=None,
#     form=None
# )
# Files: ['simulation_1.root', 'simulation_2.root', 'root://simulation_3.root', 'simulation_4.root.1']

# %% [markdown]
# ## 4. Fileset Specifications
#
# The `FilesetSpec` class represents a collection of datasets, typically used for analysis workflows. It provides:
#
# - **Multiple datasets management**: Handle multiple physics processes/samples
# - **JSON serialization**: Save and load complete analysis configurations
# - **Dictionary interface**: Access datasets by name
# - **Validation**: Ensure all datasets are properly specified

# %%
# 4.1 Creating FilesetSpec
print("=== FilesetSpec Creation ===")

# Create a fileset with multiple datasets
analysis_fileset = FilesetSpec({
    "ttbar_simulation": DatasetSpec(
        files={
            "ttbar_1.root": "Events",
            "ttbar_2.root": "Events"
        },
        metadata={"process": "ttbar", "cross_section": 831.8}
    ),
    
    "single_top": DatasetSpec(
        files={
            "singletop_1.root": "Events",
            "singletop_2.root": "Events"
        },
        metadata={"process": "single_top", "cross_section": 136.02}
    ),
    
    "data": DatasetSpec(
        files={
            "data_2023A.root": "Events", 
            "data_2023B.root": "Events"
        },
        metadata={"is_data": True, "era": "2023"}
    )
})

print("Analysis fileset:")
rich.print(analysis_fileset)
print(f"Number of datasets: {len(analysis_fileset)}")
print(f"Dataset names: {list(analysis_fileset.keys())}")
# Out:
# === FilesetSpec Creation ===
# Analysis fileset:
# FilesetSpec(
#     root={
#         'ttbar_simulation': DatasetSpec(
#             files=InputFiles(
#                 root={
#                     'ttbar_1.root': CoffeaROOTFileSpecOptional(
#                         object_path='Events',
#                         steps=None,
#                         num_entries=None,
#                         format='root',
#                         uuid=None,
#                         num_selected_entries=None
#                     ),
#                     'ttbar_2.root': CoffeaROOTFileSpecOptional(
#                         object_path='Events',
#                         steps=None,
#                         num_entries=None,
#                         format='root',
#                         uuid=None,
#                         num_selected_entries=None
#                     )
#                 }
#             ),
#             metadata={'process': 'ttbar', 'cross_section': 831.8},
#             format='root',
#             compressed_form=None,
#             form=None
#         ),
#         'single_top': DatasetSpec(
#             files=InputFiles(
#                 root={
#                     'singletop_1.root': CoffeaROOTFileSpecOptional(
#                         object_path='Events',
#                         steps=None,
#                         num_entries=None,
#                         format='root',
#                         uuid=None,
#                         num_selected_entries=None
#                     ),
#                     'singletop_2.root': CoffeaROOTFileSpecOptional(
#                         object_path='Events',
#                         steps=None,
#                         num_entries=None,
#                         format='root',
#                         uuid=None,
#                         num_selected_entries=None
#                     )
#                 }
#             ),
#             metadata={'process': 'single_top', 'cross_section': 136.02},
#             format='root',
#             compressed_form=None,
#             form=None
#         ),
#         'data': DatasetSpec(
#             files=InputFiles(
#                 root={
#                     'data_2023A.root': CoffeaROOTFileSpecOptional(
#                         object_path='Events',
#                         steps=None,
#                         num_entries=None,
#                         format='root',
#                         uuid=None,
#                         num_selected_entries=None
#                     ),
#                     'data_2023B.root': CoffeaROOTFileSpecOptional(
#                         object_path='Events',
#                         steps=None,
#                         num_entries=None,
#                         format='root',
#                         uuid=None,
#                         num_selected_entries=None
#                     )
#                 }
#             ),
#             metadata={'is_data': True, 'era': '2023'},
#             format='root',
#             compressed_form=None,
#             form=None
#         )
#     }
# )
# Number of datasets: 3
# Dataset names: ['ttbar_simulation', 'single_top', 'data']

# %%
# 4.2 Accessing and manipulating filesets
print("=== Fileset Access and Manipulation ===")

# Access individual datasets
ttbar_dataset = analysis_fileset["ttbar_simulation"]
print(f"TTbar dataset: {ttbar_dataset.metadata}")

# Iterate over datasets
print("\nDataset summary:")
for dataset_name, dataset in analysis_fileset.items():
    num_files = len(dataset.files)
    process = dataset.metadata.get("process", "unknown")
    print(f"  {dataset_name}: {num_files} files, process={process}")

# Add a new dataset
analysis_fileset["wjets"] = DatasetSpec(
    files={"wjets_1.root": "Events"},
    metadata={"process": "wjets", "cross_section": 61526.7}
)

print(f"\nAfter adding WJets: {len(analysis_fileset)} datasets")
# Out:
# === Fileset Access and Manipulation ===
# TTbar dataset: {'process': 'ttbar', 'cross_section': 831.8}
#
# Dataset summary:
#   ttbar_simulation: 2 files, process=ttbar
#   single_top: 2 files, process=single_top
#   data: 2 files, process=unknown
#
# After adding WJets: 4 datasets

# %%
# 4.3 JSON serialization and deserialization
print("=== JSON Serialization ===")

# Serialize fileset to JSON
fileset_json = analysis_fileset.model_dump_json(indent=2)
print("Fileset JSON (first 500 characters):")
print(fileset_json[:500] + "..." if len(fileset_json) > 500 else fileset_json)

# Deserialize from JSON
restored_fileset = FilesetSpec.model_validate_json(fileset_json)
print(f"\nRestored fileset has {len(restored_fileset)} datasets")
print(f"Dataset names match: {set(analysis_fileset.keys()) == set(restored_fileset.keys())}")
# Out:
# === JSON Serialization ===
# Fileset JSON (first 500 characters):
# {
#   "ttbar_simulation": {
#     "files": {
#       "ttbar_1.root": {
#         "object_path": "Events",
#         "steps": null,
#         "num_entries": null,
#         "format": "root",
#         "uuid": null,
#         "num_selected_entries": null
#       },
#       "ttbar_2.root": {
#         "object_path": "Events",
#         "steps": null,
#         "num_entries": null,
#         "format": "root",
#         "uuid": null,
#         "num_selected_entries": null
#       }
#     },
#     "metadata": {
#       "process": "ttbar",
#    ...
#
# Restored fileset has 4 datasets
# Dataset names match: True

# %% [markdown]
# ## 5. Integration with Preprocessing
#
# The `preprocess` function works seamlessly with FileSpec classes, and will promote Optional types to concrete types for successfully accessed elements of the datasets:
#
# - **Calculate file steps**: Automatically determine optimal chunking
# - **Extract metadata**: Get file UUIDs, entry counts, and schemas(using `save_form=True`)
# - **Generate forms**: Create Awkward Array forms for type checking
# - **Handle errors**: Skip bad files and report issues

# %%
# 5.1 Basic preprocessing with FileSpec
print("=== Preprocessing with FileSpec ===")

# Note: This is a demonstration - in practice you'd use real file paths
demo_fileset = FilesetSpec({
    "ZJets": {"files": ["https://raw.githubusercontent.com/scikit-hep/coffea/master/tests/samples/nano_dy.root:Events"]},
    "Data": {"files": [
        "https://raw.githubusercontent.com/scikit-hep/coffea/master/tests/samples/nano_dimuon.root:Events",
        "nano_dimuon_not_there.root:Events",
    ]},
})
rich.print(demo_fileset)

print("Preprocessing the fileset...")
dataset_runnable, dataset_updated = preprocess(
    demo_fileset,
    step_size=7,
    align_clusters=False,
    files_per_batch=10,
    skip_bad_files=True,
    save_form=True,
)
print("Fileset after preprocessing (excluding compressed form string):")
rich.print({k: v.model_dump(exclude="form") for k, v in dataset_runnable.items()})

print("Inaccessible files")
rich.print({dname: {k: v for k, v in dataset_updated[dname].files.items() if k not in dataset_runnable[dname].files} for dname in dataset_updated})
# Out:
# === Preprocessing with FileSpec ===
# FilesetSpec(
#     root={
#         'ZJets': DatasetSpec(
#             files=InputFiles(
#                 root={
#                     'https://raw.githubusercontent.com/scikit-hep/coffea/master/tests/samples/nano_dy.root':
# CoffeaROOTFileSpecOptional(
#                         object_path='Events',
#                         steps=None,
#                         num_entries=None,
#                         format='root',
#                         uuid=None,
#                         num_selected_entries=None
#                     )
#                 }
#             ),
#             metadata={},
#             format='root',
#             compressed_form=None,
#             form=None
#         ),
#         'Data': DatasetSpec(
#             files=InputFiles(
#                 root={
#                     'https://raw.githubusercontent.com/scikit-hep/coffea/master/tests/samples/nano_dimuon.root':
# CoffeaROOTFileSpecOptional(
#                         object_path='Events',
#                         steps=None,
#                         num_entries=None,
#                         format='root',
#                         uuid=None,
#                         num_selected_entries=None
#                     ),
#                     'nano_dimuon_not_there.root': CoffeaROOTFileSpecOptional(
#                         object_path='Events',
#                         steps=None,
#                         num_entries=None,
#                         format='root',
#                         uuid=None,
#                         num_selected_entries=None
#                     )
#                 }
#             ),
#             metadata={},
#             format='root',
#             compressed_form=None,
#             form=None
#         )
#     }
# )
# Preprocessing the fileset...
# Fileset after preprocessing (excluding compressed form string):
# /Users/nmangane/scikit-hep-dev-4/.venv/lib/python3.13/site-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `str` - serialized value may not be as expected [input_value=RecordForm([NumpyForm('ui...s={'__doc__': 'Events'}), input_type=RecordForm])
#   PydanticSerializationUnexpectedValue(Expected `str` - serialized value may not be as expected [input_value=RecordForm([NumpyForm('ui...s={'__doc__': 'Events'}), input_type=RecordForm])
#   return self.__pydantic_serializer__.to_python(
# {
#     'ZJets': {
#         'files': {
#             'https://raw.githubusercontent.com/scikit-hep/coffea/master/tests/samples/nano_dy.root': {
#                 'object_path': 'Events',
#                 'steps': [[0, 7], [7, 14], [14, 21], [21, 28], [28, 35], [35, 40]],
#                 'num_entries': 40,
#                 'format': 'root',
#                 'uuid': 'a9490124-3648-11ea-89e9-f5b55c90beef',
#                 'num_selected_entries': 40
#             }
#         },
#         'metadata': {},
#         'format': 'root',
#         'compressed_form':
# 'H4sIAL9aDWkC/+19fVfjOLL3V/GdP+7ALnTHzguhd3vOgRAa5kKTIWl67uy5j48Ti+DBsb22Q8Psvd/9UUmyLduyk9DDdhrX7swQVZXkn0pvpdLbv3
# 6YuVYU/fBO++GazPzQPgpD6+mHPe2HW4e4NjD+8UO49IDiLheO50dO/HTs+rN7IJEH4sXw42zy69g8c+bzyAyKhKc0HMXWnOimbs6s2Awmv5PY6H4gN
# zX8dkvJv3U8sjKRvJAiJbNVCOtJemp6O5P3aDCS5FiY86c0ymfizO9iczC+uTEKtBNCAko/BvLAcv3L4cQM7pxcMJZD0XIx5IS7SBYWIZmVinoDPwwn
# OqX9TLiAFDatkFglIonLtMXS98bLaRyeWrPYD0v8BIpMC60vI45h6JJZHPqs7iS/TZu4sTWMrfEgTw5b7eHMcmklPHPicZKPHP+M8k9IEN/pE/8LCdV
# Ck3tKH1XSz4bDUZ73+FQMD8MwT/qjECwKEFBAnnLuPVw63jIa0R95jkfCeekTQvlp+M4nubATtO0cgVa3UXxN3AejSKbE88jPURfQwnMEx3NGp1zStF
# y3mjm7m+eZD9YpjaAf3Oilr2Qsz69mGjWscrzglgNptUs4JVYRpaiXWThfH8LDXDByiEMKlKK+KcjJ5CxHmt1Z4Twfb7aMj62I2EqiyXNp3ujFIju3H
# /Nw7fm5XciQH/teUS6GDmVQhvHg2B9JFBP78+jYiRdWUM8ttYmZ7z3ckNhXZ6Mk7kSj05nl5RG7fhTTlhzV1B7z86jfqucfruBf1NbA2g8kEocrJS5q
# anLdJ4wVHzBWJL8yD8bKPBjqPESE2B8sh/XMp641NwntWo8tmw45zvTUcWMS8nHLO7ViMYLwX+nYIYIwsA0ub46KpGTgk2gnJ8cPFyqa6fmXJyXG4OF
# YRasSvlDRlMJ0/C2mfDadShSbSkys+eWJedb550P0y+BEzZxOq5mTatbnatZvtWn+djab1XBro1azINoFdCRKLnyxgmueKWjKrwDVj+9IGCl4VZqq1F
# M5M2L0FKFktEuCkX8b26EfSDTPmOpysJ0LitEjCclZp8ZNZgoJWmwt9XzQyAfb+WBHCrLOXwpHy+nPbDzQVUTRJKNwxIYDJpIETPv66oGEw9jIkxPdp
# IQkdxkhzodDMarmqWAKivHH+0A8Cujov/oQSgPJpzJCUhIZRXxcIsRSihkrn1YhoXwqUhIjK0zSgJ9SIiwopcLCWTI8mIs7539pli9Z1c1JJuNzQqCz
# hHgZlSnQtzIyWNE5rcnhBGeOloDNEQXiPC2BTUKLVkxz6ngPVpinRbR7J6OT0zz1C0kadkbjFU8KG4VwYN/qZVJByrH1IsFICunGiSbWUrB5QCooQZC
# KSlCywkoIcT6cmWMZraIQBTcrNSr3OVXGxdlQTNX80Jk7nuX++vnD5BOzeTzKHNm3OeFcGASuCdes481zgko6RBhD8eRECxRvNM4C8m+PttRJaPHJeP
# I7mdNk4T9yQaHtNFy2sVUsYWNnLF4gWTjOBVVTDDWzmPBt6C9GN/m0kwaXUpzojOpgtAyd+KmsANkilYinNOULapemEZJORzZsilZNyaQpGRIyYVAk0
# C7g4VhFTCVnd8PF8DQLnWUBUVJ8pAhng7PTfHD0KSUkLYZP27MkFFN4NuQR+aMekT4qCjbrWuHXP+du8jM3BrJcXZN5MgNOwtckRUOE1ZmMagWakWVJ
# jIUJbDmCCKfC3sD3otiJl8SL0y+lHoeMcrmUQsGSf4A2MPNskv0692Y+rZLzhHITJO3Q/Ah+nTQwTX/N0l9LO+PP3WX6O/h4cZUF+G/WfYhBSvw0g1x
# IlHjK5GWRBJNCTtnSQCS5hpIQSxl+XZL4kzdzl1E89D4FJ+CC+bWG998Jb+Y//PqrHJA5/50GxGfz34ycuefcOrQZzkhKS/1TUC6Musx8MMlv4RzhwT
# +knzJDKIr9TmbrLJD3jCSkzCvCKIkieUDRVZUZoptijHKPWSQrpTt5aaG1ZWqDiZ9yNiMyX9AqPvAXQUbL5RfM28uHTBnxfSGv8dIjAaWNsm/QCeKF/
# yVPEO4NFszG0kR/wvRjQW9MB05HtCtOYT0qCS+sJ2Hk86wk1ZPjyHsrGO02sS/l9O+gZ4+lmI43cRYkV2Wc6IPrTy1XImRdviAIUCnF9f2ISMkuiO0s
# FyXCiI4Sgfx5qAZUoTJl6cZF0oMlhYLbPBcK6bxUZkXlyOH7fAIxNUXmJDy3LyAT3CZIJwGJqZ90wklYdjXmpwMiJNyMiYkvGkUSpABPimHuvEpmDqV
# mUGaIhpCffORmHsm041AKpC45Ec4qZEIQ3qjMv1Vg3OglljToSNSscieoklorwkpvWiHJxFsmyE40ng1ja3isoA2LKk09PAXioUwMnEfijgmRgclenJ
# HjkmUADXFJzvmSjCAFS5t4sGgj0eYqojf6JIWgq766muQpFwllGQSO1PNn4TgXTPv7a+uLJJ6EZFYqektzan8IHfv6zj+1opiWzxGvXArOgPaNobWCC
# wspKyRY9bIho5+CetGPZJl8EWYzJyGJaG27IIFoi0WaNLfJ06UpTp6RDeIFeqwmSzZAnnNnwTTnyJvxGSjtc45msfNAS12YvQVSOg8tkJNZZ5GsSoOb
# VSWi3lKSDSW1q6AyO0yZCuMYVYxuMvtOssx+5Qx8mZTY+BItNfMFLZusy2a3CCaOpSTYzgWz6bukPx7IGdWCljiWsqCRD7bzQeZY8sTkOpsS28IYAIq
# wtNjPP5JfIkfw0yWWPbk/EWt0CuqIZyGjjmJwO9EwtybkyTv89nhzkSAEWQp8VSO6WsaRY5MxNRhpU/Q9kvLTJINlMrZBiCrryIsdau2XKUZL70vUE+
# YzXFLqwYMR6DdjUsf8ncR17MVS4kpZ4iH7mvvMBIXWLo98Obnk0fMM37VPLhUkJqtXMVSJwEfzzGyoZKVMZtbTpW+nhGy4y+ttYMVKoqxPxy6oPSWUp
# S6XWfikCEIifQQdRTKjqsAUPKm8FNyFBEFdGoyeK4yMki+LAl2RQqEk7qXxTgTi7Hc2EZpQw+5q+jtj8Z+JoAglrTNhiiRF0NXz0hA2jRzFyEs4dl7e
# EfU4JUgVSNBu2YrQsVjNmxNvEk+tkI863hU41ri/Rvw0Wc9C/3q2fyt+Poq/T+JvIjK7cwzxM5r5IUliBg+R9POD7/OPjdl3xjem7RJP+kn7jiTEezj
# +KyMHR97cza+SZs5BFRlcNAVXNaX6HtD9ZZhn3Vl2qGBVRSnLA3HOeAJOpVQpSTY9yOdFJiX5EDZjXjBPTEShgt469nLmWC74s7PZvUzNL6nP6Gjg0Y
# 7/PvVjyQQ+qZQpibUu01jvJRPGWf2gP5OB9yYbdLMqBkUsRtebZGQVtW4sat1Y1Lq8Y7hASXRwoUcOneWxea5JjX9mFZ5dTPg07NQJo3hkxXeCatJKM
# Dql2W73WiaVWVxShGK3kMzt13E7rVquUck9mxx0M2a3yOy36ph1MQ+VMcGcpoC6lPkRfvBJoszpljgn/nLq0hl81/wURI5LdcoptP60WTQ6sTXZfJ3+
# KEZqZ8IHQbckniSZRAPEtL51zTYVNtIPJu4DSeQqIJ5ZJ5d+18g+e/m5zD2o47bbtXE7ULHpeEVnfBO26vAhui1J9UUSl0muL00olL558psJJdXOimd
# 1nEIEngEAqsrG5bKW2T4wqxTAmHS4owkUS7Rjts3jSEX9mZZCmQ7USXhvnjhR4FozPgvOi1z4XyB3H33vmkS+Z3lxbYS2CWza8NvcSijwKGrzBGZP7c
# tl+VujyBnRGkRWQGJNNVCVEXxDtPmMBHX7wqDqyilBphcqOmexwlXFYQyo2xWsgypG3YcgvWruQZnXNi/0sQODL239fpj8LFQJPhxkLUXFPWipqP2uX
# I9bqlZEGXoX9sCA66zIOKhgsKQqGGmDLfFPHN4aBArIzZXnPlEdiGb5Id/q1GiNfgWjXZW/tlHF6K7FoACHHy4nMr8KQ2c9DBVZVvV2JlPjIJ2sjk5p
# wzsbjduppgehH0UX+sqELpkD989IaZI5q78uoZV5Y6LnJ39iHjdNcWVeKxI8m3ToSH9MrEUU+HFGbbfK1N9I6B87VlRi0A/Sri39VIW6aFNR670QvUo
# 568avUMW60Veir9DkxrlYL52VualNprMimTZ0+vd6InVN5ivSqay5IqEEzdoJrgC2cXqrAK5K6KCyArRyCfBBsBy7stzXi15V3OvEbhVUotZQ4Yu5YD
# Yp+eTRmXxIJ4bEpibOsA2zgePR5NdV/PZxlUhvtciBQiSzPLh3Kk8zUssBrCu9lQ/R1G5IGJNHRbJKAZnb6Wbc9ji21Gl0WutIdXPAjDaNEj+aBi3nK
# ro58KOFM0tWizKLCQTbLaWgOYQC7qyQrxIqzj42QlQhSLVBuVY8u1NG6q6bevfPS70y/6pSqcjg2t9dgWp9/HnQtOoeQH9A2+zNDZ2uLftZSJI5zMkc
# KmUq06EznnWSyovVpcYnrmumWRJemTKdpG2Sdk7c6LLZYsu88hxLmva0BHkkT7FSammaZKTyd44i8RxVN6TfXTkNedKe/Zbnnd1U/sq1oRtLefAhKXj
# isAnq0QPpKGg9Ba2voOmqyIbqK4YqybahxKMgdltKlObZ6c/DgQprFYeqoJJVnZ5hVLLaxQQTj15WdAnF6JZ9gkVKr0Tplyh6OZqk85RUTkrSt+SVLJ
# G6JVK3LNXNpArZLeS1kNFCLgtZLOavmLlizorZKuapmKFibpRZOf1iF3JDKUaJ0inF6pUo/XLK5WjF/AGpnFQxlwxBmVTOi6LwcjmUiIaK2FFF76mIf
# eWHlPENJShDmayi2uYzL1O7KmquxM8mej8XNLq5YPsgF+y0c8Gung8e5oK9fMoH+WA/L6y38h8Gl/vo9HI40fmPM/bj/GSSbAcvC+qJoK4UPEgE+10u
# R//WiR0KsUOlWD8ROxBiB/VidR9dCR4EjETAqBBoJwLtCoFOItCpEFBomjkpjydiw/f4xmxnM6NK4KsjKTKzOpIig6sjKTL9PHisRrdych99MFCEbBK
# okZ88BeTKI+smn4ivqho1ySrlVlWURG5VfWE51uXs6zWCFXoqC7ZlwXaNYEcWLGO89D1fbGQTA+v6sGvjrshJbdwVmauNuyK/F/pwcnlm2TB7i+RlSu
# jDciua0B3BfDwewAp0NqkSvMMant6qY+o1TKNbwzygduPx2VDN7NcxD+uYzMCt5AKiam67Nm5bHZcVlqHUUcqqjFaTZLtV/zngMXfzGYWnEhJtepUs0
# 1nXZOeI7qW5FO8Ti2TuXQKjs8WmaoJQWu2jHLGMBZyIVt1iDxwc6JXiUIibyBsbykNRbiLfaV1ajycktvSgJxibRO92vip6z9gk+vpq30DjGyh7Az3n
# AOi95+ZSN/qbRBWLsazFng0zrSs9RX2+5klLpLQvQ3bvVIvJMmvsWiikusE+h7zrB1bDyltPoDnfFJGvHYl+8cT5Ob0naOPowPmqBNLv01/HcVa4etD
# 9akS8nn5tomq3nNr7llChml4u6XStw6AY0LF2K5idOuZBHRMG6hpuVVymGzWvXxuzL3jp1iilRFXasipMz7fcuV+rkXqZgzVkhH5WCK1IKctRlUh/nX
# RKuqsTVH+QbwqRuo+qmsprc0UXV+wuVgtLLtp2vs2sk/4GsXKj5caN03hOV5kNy2wEybwyk9AJEqpJKy3/R6R4Y6wpZl4fntsZypw07Z/oP/qqRMtit
# Yl24Z9upXAxm8kupny4W+AfdPPhwwJfLyaoF1PQi0nIDkIu0WoNj9MFcP438gsy+hoyxhoy8K2zoa6AMKwgr0iRjvKgaJjGDHVmYl8WVbi5gDk8Zlux
# 2GTl55/bzLED1hENdFqtk2FstTdNpCMn0lMmcrgqLzCJWCHRW5Xdw7RCJ+66bB0iENacafDqa15dQwpc3jz6eEIT5Qywmg6fH7NbjjmiVkKf/ocJQQR
# 19BEcboQjlCyh7vMT+uhXJSWaZtecfPFHoe/Nqeld3OOgYJ2wfcIttlPSvNDpB67GSl6ykE8ne5VCqyJWfbRzbbZISM2t65WfXikN+zdhh7NRZCbbny
# GFoFvD7dbHVGU+L0FCI2itIXJZJVOjMhlnKb7YIgzMCg2VJCoEauJ16nh1H5xcdtuVamEHKJhQvchH/0KXAfLhjJpCdCSj/892JJcEaL8CQ52KYzBmS
# mebomHXL4z4fNkYiPoaEibfnaTXSoJHZWVyiVAxRenMwG/cy9MVHsJeq1rmQMgc1MgcCpnDVt1e8lIJ5Dex120Xr+wOitvg67edtz/6/Aa/iO0BKfH7
# an45pugzO6VN2eVEEtF+WbRdEE2BJ12yIk4RSTFOp2KfOP1aVcySGlprCtLR+YC1m1bs06GQtsGTy85aQtnG57NJJ1s4ZQuGWfmdOL+zOVpKSC8n4sK
# wlLe2cDnlXo3wJin3uoqUz9m9Mc4DkeCuJZdOKOmAfPn7771utly5UsRYLdIuTDwyservrZI01pZst/I79hU7ruXljDabhRZ8zvwQgCLm2UTPn9zpwy
# Xbd9TuNMcDcAfkDSh1/RSThnZ+Lsxmezfcguwo/JKSWaCOILrbWiGJ2W3VMAsxey3JI9aRt2TxfTa0c4bKC+Y3GDg//wwn4s4mk3ZLWizqVXjVRBqbJ
# aC31k2hW5XCRipXyhc0rpKRt4FV8+rU3WaWkNh502qBbdYtDpulNbuaWH0Rq79RrGz43SRW3UaJunhQVgfS0uLBxrH7Uuz+xrEPpdiHG8dOc50ECvG5
# 6ai30oNs5rEVhsQ1x8SaL123YN8aYqJRK6RnJyif9KBgBesd2MG4IoF+Cqfw+a5i9iRJm54Pl0NkO9pFtE4KqFIAQFUw+UcVXOh/aAd1qFrvKG4PBen
# DSuk1pPIdef54RzYe3UuuNxbqqm08LtmTJXt1kgeyZKXdmNtqK3vyc77+ZFEpm7lLvX2VD1Zs38sNDMYGst31Zas9nGVZxYqT4uMH60iln62V6ib+nZ
# sJWAEw8NjJXsheblROsyxLygLtVQKdFQLJ6ma1QHeFQLs2BbZq126N6NBr/rK0bJZL86BrUkOSYuu0Eh/tacVIuTKB3OY9imXsPIptoumqqZy0ERx2q
# qPkOF2J0zPzydD++rBaOAe+sN2w27p0vOIeWtaceqnrMKm7tMperCOTGelSL7N2hGpcw8HRBdvhl3Vu4wG43PvmEG5RFN466CelXZR3T5EziwpBdtVF
# S0XUVURDRWyriB0Vsasi9lTEtI+7tjzbXxRPOJZOPB65ztxbJO/kyJxcBnNUXUk1lNS2ktpRUrtKak9JPcj2yXbEzQ7yxRMJraOgdRW0voKmt1REeTd
# vp9AZJpRuidIvUfKpc5JR2KiTLEqYzG7XT/1wNLomtyohYx2hdpVQmsaZD9e0p9c4yhsuVDx4FIc9yxCyu0jSmbaafKF/8gLLCYl9vPRmd8dB/Mieoa
# nhj1yZ/dGPgXh1nZHMwcnATA7NmW0TTE/DnFyNYOXiZHR2bgQ92rxpnjtpBYUoF8aMnZwyuyxKS80LClzI2MffxnKQWmnjp4VMoT2Ja8XEnkImJDc+G
# 0LPjkuUYamCsxtcBr7rOhFV39EttWuOpn4Yf7CCkmzyNaYyEq1I6xwuQ3W8ktSFtYYQS+r4V4YnJ7HOSVV2lct95nHQgzA1wdaUN9lM6zmxpMa2UTT9
# edGM50VrPy9aZ+NotfJ6v8VuL4dbia1HRjfZJsI/K4HayNSA+4rIxnqRwZLsCXtdaeCng2j0z1aQLbixYKZuGry8BnuR0VuH5uW1tNbNuUYttxjX7Ih
# L46oTyImkZ7OHJc//2ufiC+64jY/Bbxa/Kt7Gp+XX+2yn9azProq26nOr4K74bHX0m+PT5CTtOof5y9HWO8VfjrfW8f2VGyWSHQrptoS22JZQdBau3O
# NQSmHzmKUtEZVHaqpOklR4suqOhqxOHu4DYEd7x9aCXTtaychvb2K8kmxud1aLu4bLCRc5qmhl6cLOL76hvJx2gaOKVpaWHFDJMoFYo0ycPjo4yKht1
# q0XLJ5QltZOB0dVi7BVK9ODo0Qinbsf9s1+2zygw2JXOUHXA8oNDqAp6aXIeqtt9vsw/X9WbF03aQ3vt54VWwZejkajGPVw147TZXF6m8SRM7ZmHCk7
# tbhrAdYiKZ1HbsuXHlKclJHbtK4fbB5lrRi066cWPy/xYzNoGc+I5QXPi9VRbMGifQ30theJAyW/B6p639Nzksht6Dwf9fJ+ihxVV1INJbWtpEoXUxx
# SYrf4sYyoq4iGithWEaUPHVBip/ihjKiriIaK2FYRCznqqHLUUeWoo8pRR5Wj0of6KtX1Varrq1TXV6mur1JdX1Uh+qr60FdVh76qNvSrKkNPpbqeSn
# U9lep6KtX1VDlqq3LUVuWorcpRW5Wjdv5D6t563SFl9VpNr27bDxMx6YSsZyrFklttPctNbrVlz4LCsbiPvhMRHqdMp/1HgTUYD5jJBQfpalgM0Sfvg
# XY3NVJGS+8W2HP27Iss0VNKjJcBCevEwI80jqkVokB6R3kXVkTCIbxvXmAO2TPUlj0gris0B+uQTuw8kBrRY3/p2Vb4NGSvshQEy++vZtnxfRv2hDkz
# 7nri8oRKj2eKVBhsWLMs8OLwfnT1QZR9ShUvBJyxm6bZ1BxuT3WX4FMsJACrovSjTKjAAuQ8oYHl2Y5txaQsQe2/ZSlRRczxcrEgYam40hQq+Dx/5sL
# yniIoVdhx1G3/WuTHvr9KxPXnwzD0w4nvX1LRATyNJeuMmrOSGi/0azLz0yuiL3TzyP1iPUXwEIsgwKVebLS9Jre6eXM5VNDbFfROkQ6HVD/APYp6Jc
# eo4qi+L/FK8T768dV1kUgpKrycXIJLaZATiSq7pEWYe5tFIPFHi+CvKXNDNzRswhMXkPb5/oizycTotXidUXP7ddx2q5Zr1HI7ZS70/3SKx2SKLKNVz
# TKqWV3YrFvJ6lSwDipZzANC+/gaOKmIsZaIsUKkIgd8u2/bAI6u4nQqOb0yJ9s00zZt2Dp3aT3qQa9Cplui68bquEZF3K6a3hZ7eNhucNo+qJyU/Epx
# 8FpuIr5Z6u3NUodJzibivXrxTLLDt7DRUu10zevF1YMbFKU7avWa4Axqt2QQaao9vpaQF+dbO1Ug1OJsY4KE4ivETXb/FfRG5YgG28KQRVwBq1a85jt
# 9pqxU7UZ20rJljn9ZQ1yUUquilBQxxD6inNTh2mWW9B/DD4aij5C4in6CZqoYzpphiXP1S4k0VpFMfgwmR7WvRW9hsi2rvBlwYivoF8VhgOvwlNKYHZ
# VQV4EgoStgSKzV6dZJGEFrdTJCqEpCV6hP76sKqQ0fSgaMg6ArXaGYk6IfgztfTvnu29J4XxBhbaDcZVRKgZ1T29nIMXur0gebw6hACLxODU+Zs41qG
# Ktcww+HKngdZd0pVkejyK+oc51ShVPElCpULZNvHop9vZifpErIFaVdlKnJ82G5KoI10i3R4KCUQrRrHqholZ0J5xYSot3mQUuu/7Qm6WlvB4GuFDg7
# FevuUrBQ7TlZbxWCFVIJGWz/MZ3YeHzXg7RfIRU2WoWgMkmjtUZS7VYhqEyqk5fK6+GwHAd2CbSkUE8OUVYS4psuAFt+30WOdUxu/ZCoefksFbeDXIV
# TJ67gyfHOBkcXJpu+X9I6DJ4FJSPx0AKDZTHN8RnLoxw0Wvlgt5sL9lulIPNTsf2SLbPLrJR2l9njnUywnf8mC5bjdVrKeKkgNQF6XEQX+zqZUb2OeJ
# eZNUXxfNY7+ax3ulmQWQJ8LkENojitVkV6p4Lez+jMyOGgCq1RxdTrmEYN81DiZVuRBA02FimqYdV+owvdLFlL4psGnyuxTtrxWql2y/JZL1UnzI0tV
# i+l0igLiK8frEywtypBIQDGYicb/CpS669Krb9Bau3WitQSgZrUaMBZLBewE+zstMVcQOACoX8TAWov8akn23ssZqFieO9IlnLlBBXWXtIUOlIRFlJI
# Weuk0K5OoQJDP61GeYs8z+rlWbAB84Oes6YoMVeD8x6CErdTy+3VcTstNbc0XoMZJjkAMtWs4PcL/F5t9HZBDZzYrY3Tq0fUr2bz2YB81oh1S2nPWS3
# SzUQo5YPRzsPuys2tkKVeasTp1RyjktOt5BwUOQVTOyF1ZdKBAv1BDfocLxcvt8WWhsUI1xYFzqtbN1eRhUh+JpGMjIdddrihaxrSXFmQeJL8pqjTzy
# ftoCVFzia+IpRNbhNCapxWGnCcUTEGcXdtsQBTaldF5a2+SBVdZpGqlu2rqB0lho6hpCqRpXU5IfSKBMWH04FOr2JkxSwzelUxejUx1B/vVyXVr0qqK
# h/tVkWMdqsqhlEVw6iKoShp1q2Q8GxYohotBSlf1WWOOmlDmXSnQroj92/9Vj3/sMzvVaSrSKqvFs2mNRKJf7TYuVQLmOKdGVmo3S1TKpTZ7iqhddpr
# fKbTW0Oo1ypTKrBUaLSvKtZygRxWJXuoSDZvHeqV3HarzIUO9fhycloinvxSIg1Vcldloq78Duzu+0X1Lc4YVjFUHzCUH+goqd1yVvSeUrJfIqjECq0
# brK4SQZVNSh0qqYoMGsWPtgvhIl+ZoYNiuKyJA1U8ZbYPVUT+DFGkpqqUkLCG1SyFOuBNXAWpomMRTMCr1zRnSaxTIwYnGwzFEAP0/NAzuZoML818yM
# iF2rlQYsvyXafU9MgNlgkVdsjQhtA3K5ndSmbf1A/qmP3iwmZ6jQhbm+q3zINWfoHkoFUpT2Ewo0+SZ2G1fGogKq3DnHhmEqbhzCjMSOMiqV0Ml0XM7
# vgXs03/bV3VsTLvKGwMzhy+MCc5rIy3WSzYcawkqlDz56FLesoY8rfZCoH4dDf29YPqWPmsCsqKuJ1nfK+b5rX6aKCKKe3DkI+2SkFz5gdPP/wPJdIp
# QEy8OPrhnfaPf/0wc+H+q3faDx+Xi+DpKAwt9v56kGySAtbS8cThacfzSGhGd1YAjH9AcoEVWgvCdti80/71g2na/sw0IVq49N6yfebxE+1QqFCWlhn
# /8H+UceuHC/OePFGGt3RdSnpRQO5y4Xh+5MRPx64/u39BcL3OxuAI7F5766og9TpfCenW9a3nKCyINf9Wi++IdubM55E29SPf06xIc2wK1rl1iK05nn
# Y2+XVcxM0++U1Ah1bg2LSMvyH051VPwKJFsTUn+/obXZtZMZn74dPO7yTWgvgno6t9IDe7RbR/RpV9Ebzt1lbj3b91PPK9KVkNeps13UrRbqdOU3jad
# 1EFynBfsPBh7OlvDNdbLqYkhN6XIoy0L058l6l1vR6YfXibwHMl//vAP3fsm+7TaqIxU0L7QmBDvUYhaIPxDb9jfTtG6AqU4kzF8fYADe6cLQITbw+W
# aGa5VqhFywU0lWG8TdbfF212F2mjU+1yONG2qgSL2LZTbS9fts+cvh3Z1Kx3fM9yNdf/sk8nJ6yPhq4DjpPTwRG0GpJ98da8uGrneRO8CyeKr25vIxK
# nefBZkHEdPsETU2kG9M8uHTXCGvWAPTCDR8bh+irNCom1x3Tz83AQKcvwH//zGtVAYqtBudX3d+Cs1360nMahNYupWQJNOYh33+6IHw3SRlVv/0pzG+
# /s/uV3Mjul5e6HOz9+8kTHR+wfn1/qf36/HbnOYkHsoUuhhb4XaRbs3NSmVuTMtIi4vKvWdmiH/pPW1Xab1GnbxI0tjfZZ2s54sEd1scvnHJG4M6QhV
# fkj7cKo6QFHcDWHbZuEGgGaoJMsS+NautYoZgJGSetNm6uJiDqlsbrTZlPM5qntDNX2HLXBgHmPevtGetOWkfChDIcj7fykQXq0H5+0nbSbpz1+GGu3
# cNhAG93sgUpmi4ZpY+nNSBhbdKB/aqAC/sDaICuj0ZWBXRGcLF3OxKXBtKMk7CaStwvHcyw/CTZpovt2aI4H2r6mvw3g8o8meTRYWWsE7jlJawa/6GS
# fj8UzfzF1PEvl8UJPzyvJ7ZkG941rwwZluX2iOYvAmsVaKtPw0REucoYPaQsfvLzcRQ/9gUuCWJjiWkiigNrbWuyLrsKPSMSc5cLzkjgLHW8uRW6iGr
# NJDK1JC3Ce06EWFLVDh5n4Glj7+p4W3NIY55Hf6piWS6fat5rny+JN8rEuxHuZTckuNbhgVSwsVZk92sBiy01sd2qrgfP9zv/L8EgbfdKyRahoF/XF9
# CUusANzJfA98chKQ/RyeXOk0R5EOz/RbnRaW/yQNCz3nt/s/Ce5Nxpe+s3Lv7I71Ozr96037fwo0vjho15VTR5AGra2bf5r8n9NmpEcJjO5CO5CFu6d
# PfAAzpbsFhk+t7ulKWndxy5tJfNmeXsiZ76wzHMSW/Avamtz1wksLzi3zszyZqThfpTJ5EwDq0S4TahZsoU2yfq7bTZ3nbIFWWcmRtSKwwOvMeezZbw
# /tWDpmRb6qeW6+gGYpDutd7eW4+5p+ju45n5PM965cD/AntZ+t2BvRO1pnXcx7FXfbbq2dNSWWluOZ5PHZGSiSPyZw8Yi5lDc17nf0CNNUsno5AO11m
# 2mDjr8UGVMn5h6+OmPEC4kiuJwKbYAen4MApcDjdLiO6w8tsafBGpq/WGPgohRSpuFDpVxLOh/QBHQ/zjRh+h2PBs5j/xtigGtTzSPFD70Sow7iNUCT
# dLjDe2/YdYckgh686kTL6xA24E3wePBMt6jahq6ZDwYxtbl0o2da8ujqkoZ8DDguTcmxJZoozvn3MvCpxQEtbXHYKefgzz9N+PyV0uc2RU8mnzJ31UZ
# M595JjM89yg3Iuyqg5EIZOxr4o5OzyO/GI2WKEjSDgSuW83olw7tc7z5mRNHlLhLByfId6TRGYNGBzYs/Zcu/c90Dja24pLQ0HjssnpAf5dk8hXlwvG
# IFWbcG8tdkksroNXg+k4q6+GCxjvRi+STx6eq+pBEhFd/QloEHq8j+lbXkanvuy/kcKEfh42boiVpD+LmYjn38PVXmPXMyK3YivpK853uynXYub9Z8q
# jTVmV//WPcG+c/O+u94D2Dxr6h3dEOoOJQ9yusBfmFyc8jfrNhA6p/MeOHzcw4m7jT7Dco8/JKdMMqfD7rh03NegMrfbb83tA+3mhqH280u483mtvHG
# 83t47e00r/gdOaD5XjpsjiBXTLhUxRb7ldMZf6McpQhHlu2NhwcXfCDTdqta821nWVgM0f3I2yDcqnSd1Ul9g0vLviZFvnRf/X3NOcNeaNZ933t1pLu
# nqHoIsBveZb7FDkR3jnTuDtnBtD30C5nCvea2U40gy97VuyHDVKCFtwO2Dk0Yp97sCWHfpQ/OGKFT/AoOnkEFe2XdKTtWPcWv6OuSVsd4bo7fjv0r9o
# OnKrYtwnb9ck2MO0WdASt6mznt939n6ZT7SHSfhmcNFRXhbrDTuLklOf43i7q61l1azYDXSV6wwq2VgVDpT2rlmEPtlkFa56+qEmgTf9K++8mm1X8+v
# rY146PQQ9zEjZWFZfFLoZdGXzM5190lpbo52z/p84/RZNBZa1WVmohobJWKCv2A1TVeqr6jIpaT1G/vcUmuKm6UosI1bVKXVi3NlAWKmrtRvh27sLF0
# 6J2ufwVB9d68JdooG6gPt6TofqSOZ/CQN2ZTvdms73OP3fhUYLG64P2T0Ij9D97fnxHY6JmhGa4OrQH2CbeeH3gbOUHnJtsoJbGmz/NulGyYTe5DZLH
# MbTIv401O6S9I6iAXxUx+jQanTfpLneD53tK6/x7vUkZbzc04017HKdJl2Nr+xp/BQgWiuZ0RJ/CtdD0N3sDatKk5h0tp7+TOHY8Qrv2HV2zHp1G3aB
# WUIDRdAW0m66AzjYq4AUPu8OE5vyEbS6O4DC3Dudb+WbwHcv9Yj1F2q3l0pDjaUZLP9AiBy7EcqhJ6JNIgytIyCNsQ96D2AbEZjfZsGA7DV6Q4EZxRr
# oJN5Twe8N4LWti/iO2q/XrFfDn71g/deB11Ci2YkKHftvh12fyK2QijdD0Y34FDzwaGTXuob1rMImku3VAC5rtPDg214q4a4fEBjo9cBaEs6Dv7Okk5
# asOFnuGjj1JB/N+fxlrg7NxY6yhdNAqdHtbNWyJg1YfiFc+awUUbWHZvPi0Bydypi6hk1yPphc7M5c0ahxDFzUOTjg4vXQXlPY/Hex/sP/B/gf7n5fu
# f2gsEpKIvclG+xYt7Vw07F1e83ZBLYr9kNrkcNoL3pbLyp0NN2yB+idNb7Ensy3PTp05OTZw97TAXUba57e/Mbnj8WWW2BvtFN4Ohc1R0hee/CXc+gf
# O0ftloN2G/kIbnXxo1Fvc2OW99okv3IeyyFf9hl3A7thNyrAoY+YFX9KeT39Pf00bVehgQPDsi2UwMchMnfiLA880sDuOrZC801raO82JRrTrD2K4/R
# hCJ2RmPRH7gj2Owu9j3tMMxppYS8alEezlLIY7tbP4JWaHJ+fAvqsSsysxK+L3JBGOI88/YPwzK7QpaUYiOm/rUxIMZDniYVGu9CW9lftUjaBe/sAxo
# aVDTsfXlM3VdAorZAM/eKIUrqELKyV0cgQp8nb75Mb+bXwS+sF4OZWmyHwRLGIeRvTW4WwZTUc0HTfonDaBnJs6DaBPISFf5pnSuDBxrj728U1A/mLw
# Z6HZ5G50cro9yDL1UWRfCOxn2R5wjzodYC3+IhAdVoKQLcqnL97PrDB0soeE+GYUGF0qHvj7NnkwNsmD2FCydZn4S2Df7jzyq2i2WNdFmC+szmc6+Ox
# s65Qa2dp20Athq1XbnwHumZYozGbuxKswWmwt0SWKJiSakOh93OqHM5v2riq6W/ltbdI4pdngOaLKsMkbrfX+yiMjypu3Rs5vJPT3ND0l6QnJSElGKt
# V6P7kLSTGuLlHT6Hr3/RVo/mUcSc+1z7Z3pvHRX7AN0/wxUo4O9gxCHb44G1JrzX2B6eQzzaAmGT2gfGrU0wl9KPaw88KJtJ0vJiVqb7UvpsdLj9v9F
# 2dH2vlJpB3qnVZL24e/bWOL1vebVHqo9m/WaLi/aa1m8zftH63/geNMi+X1+9abbov+b/hX2ngWy9NcmArqNYK6COsgaNQIGrJgWxLMUlB8ulMjmPt0
# t0Yw9+meJGjUffqgRjD36X6NYBbGZvFNmsVovFYrOB+zOqud0r96WuWBqjMa5aX1G6hGKtkuSBrbVNL8LASxtTi0ZveRZt1SKW1qRdRGjdgLoOzh9Z2
# dIP6pq/3nf2o71jTaCez5ub2rvX8P653/+79agdbe3QVqELOtSbvFaH+nhmgSi8QWEIw3XSYGJPvxCUi0aaSUPzhBZyntBLfnyQmOk+tWe2f3DZ9O2d
# y6hid+/q4xsBQBTbvL0ayM9ZaJ0+9S+LBFymUL3Mqnbl/1UbjHJ9oSYHk2cubervYljIVfcnSzB+bvrElXidl/oDIa6mwcnWqKM2M29PXtPS324UGqH
# XZw9JgqRpvxC4SoTKOuE6jXkuhj2fPyvgeg0XuL3tvvfx3C8RxNWfPTjoEPGjDfsrXwzv/L8EgbfWpqJ1Gnry3vIl7SKZ4zvkEBJBLb7G8atwcZFgdo
# DZlRy3vb8v5yj5LygqfTwzs6A9WCZejETw15j9W51Qr1n6rBSqqAA49+NlYTUk9gaa5PZxuM/lx9vOjTp9JZ2NEp2987OBvz7b3wzKdmBYHrEHuvyrX
# AvQTdXXwXFd9FxXdR8V1UfPltQ0WA/bxodhsCVZyK1zGgXvzVJQFWjkQjvII0WRvJFHMIVge1qqy5R2Jqhgzph+ZP2qnYit1AjfDFjwYrolku7UFtsX
# OrHXY3/Ty8Hmjz0F8Gmk1uHc9pWK0YOS6heUd14bZsVXaXje4y9f0d0MB+tJyCWwLcFuwe+Xj37Y740SBteGRJteCibVHSSONtC1wAfLWZ/WVphffwH
# tYHeKdRc5174jp3vm83do6Fj4xILUFa52WO3ek+uHwJ7wlDMg9JFDWrL6Q51uCu+VQ11GrgDy0x1WyrTv597yUsYD0Abikg3JDwGvx0QpN1ge+T/Jvb
# 21ded/5q2lrD9EC/OiUhu30jvfFSnO1r1rs1XqqIpLdtvCLY8zfNVMLIcZdBOgBt10nhs8ke21FphfCeedJ0waqcRJoVszO5UUyC7TlBvC7iPQ0udw4
# dZhbTKROXirYnI8EkObz/WfPhKeipH9FsvKjSYQdQf/ND22krZhcP7ghV7tZhZV8yvy3aaVLo2w509r0AXe7Ze9H3AnbO/EhbDdbLWUwC5seLqy1H+H
# IA8WRtvSkRQ0mwuxqqLnd9zUvIEfFtP7QCx3bip0Zr4s5pcvbZMw7bnf8XPtxBZxOr8v9tJxZVC3XfBswW3YB0AqdbtZ3L4eTRXPj2PvzY1T6xfcrwI
# I2drO5+CrYR9FMC+mnrQT8+gvuFnQcABwQcEPDZPS3g3F1YdG74uEVgn74jsE/fE1jsiapG0eGEXcHg3DozKLntQZb37wzjrbkRThzSumTOzLrTV212
# r0pAgRB758fBMj626K9z+wJWnX7kt6cIJrzykAmUeZcPVpGciX9w/anlnjnzu1FcJTMJ7xOB3V28dqWx165QbSxpMw9ji5b5E9470/RLeBpdGZp1SKF
# 9ojmLwJqxi/C5TMPr/3VybUb6QoRYjBFXlLGOIiRRQId1WD4C1sylgzfVF+yu4oN/sl8bFvuzyE1UY3ZPEa1JbAMEnRSConb0t0F8Dax9fU8LbmmM88
# hvdUx4e9O51TxfFt/FIx54wQ9e8POdX/CDd8jhHXLfo2Y6WH/woE0DMjsMQz9Mnw6BXRLKy5Be+3nTiMyZDxt6QdoLTB1XcVdYw2aFskM4N0VskF4i/
# zbW4CKl8xNqjfohaVDeJ9ARkHB/Cr7jahOCHcG6Y15lOmaG93DXd7z0yKhRPekEcpwpCd7zFkp42yg9XPhwRJ2PJE1sM5Mz1l0I19F2auAFN6TwQw7O
# TGv2G2wUiT9z2J2TzPG1r3P/lkd2m3nkQ7j1opiNHBH3qdrk1lq6cEXj1InFa9I7iSX2n9wQbaa+XOuJ8pMzMjEfiBt2afHMt1lDolZo9lgzfywuhMN
# 1URwuxTo7HMukApcDqqplfNekOjNhz+bx3labhQ6VAZUsI1iHCGgohIdXxKmrYxLFzKrTdlrvbi3H3dOMd7BLoEkaO6/oqE/H11pw58fbd05z/e36Gy
# sD7Pb9YKLNlrGw86nJsqNr75NOR9ydPaE1hRLnbI9JRvty58zuaDc1c5c2iYpxdiuOBrzGW6a9ibMgl9zqbcjN2szGd6KkUqhOOL/ynDfwOvUk60lTb
# 2Cp8+siGpRxeXDY0xbEdpYL7fOoybkPQn9B7aotU8ILGgqXjufA239wdh1eToAl6aOrE7HbFe5L198LGbaxFZ7TFuFLprI9rZ0QJvzGlE4SviHhE6Nt
# ncHwkgqlM1/I/Lldo1Ahk2lUELhKG6WuB6u+7j1YmZYeLKnOPViNq1uj01VNlUlAu0uVxigi1OahRIkdHhTNtptFFpReRtnepvxyAwRbI5JHiYYMjNL
# aWCNNAXbTV4NMgMm96FVo/8F+p30HCzWt2U9CZz4noTjI8xWN4MXOJo2YN6v+dFJXa9Q5ILbKkDj/ZpbrTEPm/OOXh76FodLyk2CTzkDwM7tE3g0kTv
# RyI6KR16o262TImeY/0OIe4r77V3tZRjM3MsnZ3tNOLdfVD7QbPdBxq3N+qzw/6dT00xYb7pdHtTVym7j5r8n/Nel032FiFkbLgITCNtwDG3q25K/rs
# mZwS1PSuo9dMBibZSxGznxhmefUZoR/X4G2cJvgC7uQ4M74hRXsacb/22m9c7k3RX+3EG5X412sdKk0TTupwYaKWrnbNLlkvKlbTnEXLu6lfLambmin
# A2Y9OLpATaz/0XYuHW8E1zLtje788WAYW2wV9try5iShOt7cJRP/CwnPLPvqgYTDhWCd0q/SAX4MxsE5jQv/CtaR98TWzT5TS2B4pCQeefYvS8seg6f
# Sm1fF24XNeRRtpFFbA1aitq3MXs4JD5tXs07vQfHmyitdinKinGmpgckJJqXjaVOLzj9dzZrNSBCrbnNrnkqIZ89oU26cSoTn6/Oo32pajg+bkuM7i/
# b7ziNt8REhdlMWoz9YtFknc2wC/rjwKYot9yvWn1/g9kp+emdJtAWxPC073wP0wHcieOXDduBtkukyfc6Q9liRMM7Y0hvfZA9RsgRoroh48pXKWpQ/X
# Xr0v7PQj9jRD6gVU0I8LbIWgVuuF9/uRs/RJzpOw0XVJNLeaovF9iD7AKug8LDovkvV72ovj/R5y/v5qhDw19RzNSK+s2JaBR4IrwOWbfOXbzKzXxwt
# my2prUCD+dpTYT9+g6xKz2dZofuk+Ut2mCl2FkRkfBuxgofv3wQVr0L+7i4cxiJrTJGFdz4fw+GGw9GpNkhOC0V72hJ8DOTN/A0b9H8eDqLvATcDO6N
# DBrxBz1ctvpOs0EpCB0Dw0Yjj5/9LJ4j/q/1dM9505SyQubVYWDTXAzGPTNeAtzFTYjX6lZSRR5YMdD47daUFmYHo0qI7e37VX6T3t6blF23N5fEnws
# XIEUY889c0zWT5YySecrkAQ3QU+vZyVr4A4DVv1GzW1ruG7UPDGwVf8XtUjt2c5Qfm23FutXx/zpwvlhZbSw1+eDMSxX64PccD2NOt2XtNOUNilg27y
# V2ILuEjMHzaCp+YT4Q8ajs8ys7uf7xvwRMnwcORWG+lQ+0vSwtuUNzZ/el9F5g8zjW53dl9QzO6s/v+fWsXxzPs4Bvewb/4bJgd0gO34AO8kwnbIOBq
# wiD+Sd/W+bsKsQaQtZ/01vcEmmM2vjfIP3W3xc+dOVQ3UO82+H+r4ZZr8Hbj7b4E3K871fgzHQmO/qu/pzlvyBvNuu9rt1bMn6MHZwA1qyLY8WV5lvs
# UOVGTjIwBrH7fGNo0tuawrjiDL3uWwvh8xaOxFtwO/MXU8Yh9zl4lpR8dwyY322L3E1A7FFS0X9KRtmPdW9pgfHNjNOncxgkhAc20Nv3rdKo1ueKgy+
# kVZ/ejwSexU1rK75t08O9ju6EZxznoq82sru1rpxa7yyj2tTm1V6dwqS39HVpftGDSpOYdLafU9o2puRNFcHOr9eg06thpQQFG0xXQbroCOl+pgBebu
# E6sZf1dPHofXOWxtTw/2fnRJjPr6dK3yanj2Y43/0i+nFxGP+6y18SFzJRf35ZOd5KF7pPkybKBH4btMyeO+IPgabQbFi+Vp9PGcOkZD/rJse/aJ5df
# LiZGS++uHckDbDTS2hHs61Y7+VIx0mpsm8eguTl4MNaPl2Ro03hyviri8sgw6aL1gcsE+s2YVuCmvcmeLDnV7695pW9um/96fPo/tleUWDa/Tbn00HD
# 6GLP8WHmzlPQH6gidFrncZo9zWzZ7axuqxR5cckpHV1hyb9xK60qNNG0mrFSIZjsPji1OP4NSYnT2vdbsJttId/h7LruNNDGa1erFonYgrjz1l3FEWz
# szB2hFoFAJOgNfaWb5+bdsA3iD8n7kxc5+ev0BrP7mVzRveswjSltDsIwbu7D3FVrSdugUvd+kCcX0qeSbIDXqsfPCDdcUbJ1BXa2nq8USVaV0iwlvr
# nT3KFWHcOg29XLRtZWyJy5qbVbjqvNh149ttHmhqhKXfb2quqio9RR18KCjqtZVFTa/3KrZ96YuvCT3JRZ+krXvHby7tNF3l64xc59RHc398Am1otJK
# hf/iFb9ovlo57/jNrtG9Bu+c3ySvmNHf4meH/kzePuzT3+KZQ70H4izQoLck16hsvI6hWjdWK3tRuqDO9jstr0lJkVuppBc8Xa/eCffjbkNu9lyxE7A
# pV30qPdLnJ9oXP7yH5f3Ap9+Oyj7DQod0I3dJaaAj9VX9rLWxTil9RNjIeqteJ+2tqJTRZ2k1rfOq8HxjmWxXmSyWzyiSNcftBmm21rlaVHDqpijWdL
# miS4qVqnmiY1bPRW1m1fwmV89vUP+Sd02p/+6fYYwmykd9r9Q3OHyxvn9L/WN/82/Qv33dCtrfaSG8xK2d1hextfZyONG26nbiArR4G5G9/K3Fzzyu1
# qQzSI3aKYl30L32Uw/SqtGFrnwPpkkqiJJbf1AZtvbjhfEjfylnh12cdUbtmCmhaRI+HlFj5u3otDmr69SGE0ut/vR3MovfaTrYbMP0Ac0RvKl0acWz
# O7hr/C27FR5e2gPjbMSOGcgy+/D2XE5Qb4N5t4S71/UuGHfWco+ZhT8TMOvoj1MrZr8hRWqnUMOP/jibiMnp2aRJa9+Rv17/9Zofv2XbPBqvBvJI+yP
# +nGVeFY4H6bCZ2TvWkAaW65/bF+YE+i/4QWduNxe8PelE2/k8YrOmXd6gOIVNvXb53Ase6nSt4NRx4U6G0SlvodAyDSJmYTrZ1xdLMQuDQMxkmI+5DT
# O7LhfnUl1dxDEgpLeM5Lu0rC70E385dcnwg3n08YQG+aOhww9X4S67uHBFz/M3luVJeA+ZTHJJf/PMKbMCIBkunif4xTO1WO7rJMkUBORcgZjIlpBj2
# QI5gzCk0Kn9LVubHPBz/AyLkU5pZWonmdvKxNTrRnviq6vxIDm7JeCejcYCbsQUtQ+HNv8KRzf/yvpKBt529iXohAc4eAqXhXiZ3Byf/pULsxxQ9fAM
# UDp/9Wp/5hLLS27DZk9Mw15jrkr+ZAaJ/6Z9RTv8858Bi6d0/ih2ejh/KM83fsPrOps0jfxNC/zIYdvSaZ/lU6sizF2XDk/I7WnkceYu+YlkanYs4AX
# D0c02XR3NIBWuec9uibXJPCRsfLqlf21/i17uUwFPS+RRm/l+aMMGC/KdQH76/iD/8d1ADgm8pmNrszvH2G6k0YxOz8RFx+AnDGIDml/2dAOfukRb8z
# ClH1uu1GNIb8tTsMUOcRtvwp77vr0C9pvs3q53/+FEp9Y9gTu5PJtG/4maOvS3NY12/tjV/k5NKBZOGsmb6zufUXGY/jYXCsFOKs0l3jy+47cGNek2J
# TnzcC+Cc+vMVG+hv2IdGCdao+tAMf8NrQZs0RbscAtmlslLAjM/2gnM8Y32F22H/nefGue7u1pzHKLs+An9ANyo6yUPEGouzQaf9Q/olCWmRhPMX3wt
# iq14Gb1/r2vJ5vBIo1JiEt+gAwenrvXgL7n1IOltY5Vxn1YQ+osgTgW0HcdLJo3MD/SX/Z8WS22x3BVe5VSQ+S1EbO4GMbLkAuGvdp174sLkwqPWTEQ
# tEppMOZUp99jkiTPuns4TXfDfQB6W3r3nf/H2tBaVWXoL7rzatk0jL9h6bkUt4MVAKwFVUVL2DWoMOTXcWTbUlPmdT7sQMWlRqANrBdaKRtWK9KCn6C
# Zh3IBTng1a5HlOjWiKOra8n9hGExQO0qHNuYaOckYmO364ysBkQiXjMs8RBmNGEMZiRkBD8avreHq1ZZhNH7DKb6yyXAvgAmKvTmHqlVRRVl951f362
# voCCwdbtfH62Vutv7fqGDmLgFY/tmsA6h3b9J88k+2H8I4mrYr8PfCoQYcnUC+oF9RLw/Xyos57efleuO7pz7ew/opnOfD9glfxfkFhz1W0atMVnuDB
# o2jf13MN6dEcsdXp13STzF7jVuVLyvhvVEamjN+2Wxnb5yoywEWHrqHVKlKuuPMzDJKHlLsyqfz+T4TvnuHeTkZZLBMSeET5QoYzYw9MCfq/14m09mV
# ksv4moTOfk/DtrWvN4eCN6mIxRIWoEBWiQlSIClEhKkSFqBAVokJUiApRISpEhagQFaJCVIgKUSEqRIWoEBWiQlSIClEhKkSFqBAVokJUiApRISpEha
# gQFaJCVIgKUSEqRIWoEBWiQlSIClEhKkSFqBAVokJUiApRISpEhagQFaJCVIgKUSEqRIWoEBWiQlSIClEhKkSFqBAVokJUiApRISpEhagQFaJCVIgKU
# SEqRIWoEBWiQlSIClEhKkSFqBAVokJUiApRISpEhagQFaJCVIgKUSEqRIWoEBWiQlSIClEhKkSFqBAVokJUiApRISpEhagQFaJCVIgKUSEqRIWoEBWi
# QlSIClEhKkSFqBAVokJUiApRISpEhagQFaJCVIgKUSEqRIWoEBWiQlSIClEhKkSFqBAVokJUiApRISpEhagQFaJCVIgKUSEqRIWoEBWiQlSIClEhKkS
# FqBAVokJUiApRISpEhagQFaJCVIgKUSEqRIWoEBWiQlSIClEhKkSFqBAVokJUiApRISpEhagQFaJCVIgKUSEqRIWoEBWiQlSIClEhKkSFqBAVokJUiA
# pRISpEhagQFaJCVIgKUSEqRIWoEBWiQlSIClEhKkSFqBAVokJUiApRISpEhagQFaJCVIgKUSEqRIWoEBWiQlSIClEhKkSFqBAVokJUiApRISpEhagQF
# aJCVIgKUSEqRIWoEBWiQlSIClEhKkSFqBAVokJUiApRISpEhagQFaJCVIgKUSEqRIWoEBWiQlSIClEhKkSFqBAVokJUiApRISpEhagQFaJCVIgKUSEq
# RIWoEBWiQlSIClEhKkSFqBAVokJUiApRISpEhagQFaJCVIgKUSEqRIWoEBWiQlSIClEhKkSFqBAVokJUiApRISpEhagQFaJCVIgKUSEqRIWoEBWiQlS
# IClEhKkSFqBAVokJUiApRISpEhagQFaJCVIgKUSEqRIWoEBWiQlSIClEhKkSFqBAVokJUiApRISpEhagQFaJCVIgKUSEqRIWoEBWiQlSIClEhKkSFqB
# AVokJUiApRISpEhagQFaJCVIgKUSEqRIWoEBWiQlSIClEhKkSFqBAVokJUiApRISpEhagQFaJCVIgKUSEqRIWoEBWiQlSIClEhKkSFqBAVokJUiApRI
# SpEhagQFaJCVIgKUSEqRIWoEBWiQlSIClEhKkSFqBAVokJUiApRISpEhagQFaJCVIgKUSEqRIWoEBWiQlSIClEhKkSFqBAVokJUiApRISpEhagQFaJC
# VIgKUSEqRIWoEBWiQlSIqoCqPtnhA/HiSBnx/wPhfW0i090EAA=='
#     },
#     'Data': {
#         'files': {
#             'https://raw.githubusercontent.com/scikit-hep/coffea/master/tests/samples/nano_dimuon.root': {
#                 'object_path': 'Events',
#                 'steps': [[0, 7], [7, 14], [14, 21], [21, 28], [28, 35], [35, 40]],
#                 'num_entries': 40,
#                 'format': 'root',
#                 'uuid': 'a210a3f8-3648-11ea-a29f-f5b55c90beef',
#                 'num_selected_entries': 40
#             }
#         },
#         'metadata': {},
#         'format': 'root',
#         'compressed_form':
# 'H4sIAL9aDWkC/+19f3fbNrL2V+HtH7f2XTvhD1GSc7c9x5bk2L1WrNqK09s99+WhRdpmTZFcknLs7u53fzEASIIkSElOvXXCOU0TYWYAPhiCwAAYDP
# 7x3cK3k+S7d8p3F+4ijJ3DOLafvttTvrvxXN8Bxt++i1cBUPzV0gvCxEufjvxwcQ8k98ENUvgxsv1wOplb0Z1XSpaYyWo5YYS7RBTmKZGViwajMI7nG
# qH95DIBIW3ZsWvXiG5apy1XYXC5uk7jY3uRhnGNn0ERabH9ecYwTHx3kcYh1UL223JcP7UnqX05KpNj1ZgsbJ+o88RLL7N6lPgnhD92o/ROm4ef3Vgu
# NL8n9Fkj/WQymZV5j0/V9CSOy6TfK8mqgAsKKFNOg4epF6ySGflR5gRufFt7BFd+nr4L3VLaiwynRPjNTWfphes/6FUyIZ4mYYm6hLZaIniBNztmkpb
# t+83Mxd1tmflgH5MM2uBKqz2lYAVhM1NvYdXzRTcMiGrUcAqsKkreLot0uT3EB6Vk4rmeW6FU9U1AzucnJdLizo5vy/kWq/TITlxHSrRYLa0rrfrKTp
# 3HMlzn9tSpVChMw6Aql3q3d+moDuPBcz64Seo6n2ZHXrq0o3Zu7ZtYhMHDlZuG8mrUxL1kdrywgzJiP0xS8iUnLa3H+jQbqu38gzX8s9YW2PqATOJgr
# cRZS0tue4S+5gH6muLX1kFfWwddXofEdZ33tkd75mPfvrVc0rUe2Q4ZcrzrY89P3fiKdizBsZ3yEYT9yscOnrxO7dvR9OqwSrq8YgUItPH46OFMRrOC
# cDquMUYPRzJak/CZjCYVdt2oWvLJ9bVAcYjE3L6djq2T3t8fkp9HYznz+rqZOW9mfWpm/dpa5q8ni0ULtzVrMwuynUFHIuXCExu41omEJn0KUMP0zo0
# TCa9JU416qleGj548lY12WTIJb1InDiOBFujXmpg0Skk+emQpserEuClMIU5L7ZVWTurlpFFO9oQk7fyFdLK6/omOB5qMyD/JJJ7R4YCKZAnLuTh/cO
# NJqpfJmW5yQla7gpCW0zEfVctUMAX5+BMQ9jy2mS2b/c4MqSL9eynJceTp+sAuY/GBvWAx8EU6LSVldo2cWS34Jg6Xs6ty2dkonFO85IR8CrNVTIz5u
# gLEYVAgHpOSz8hgmGcIeIcq9qbVrrTWj9Z6L5EwqhJIn/5wJCPmkou7yXJyXKROigR/U6x5xovRyXE5OfuYE7JPjc0ViiIk8wb6nbniQwNXeCh/scUH
# B7/+futnP0sfHq3VhXubmd1Z+sLN0bh8qMs+pQpNL6rEP8AMtpiBp3NhMqsKktRLV2T6lj8pn+YUlOlKSEUr9gCYn03d9GOw8FdJOgk+RmOYCv3Swvv
# fjLcIH375RUyInP/NE1yJxbSQzgm928C78UjLXLg5LZ8nAlRKXRVzoew3n6Sw5O/CT5HBWwv9nVnNNFGeoWSkYnZCKVkDYgnJ11tn8C+XMuqdSJUsle
# 6VpbnWVnlfyH+K1Uzc2yV566NwGRW0Un1hmJk+FMpI7yt1TVeBGxHarHgGMdTOws9lAp9m0GQxxcj0x7tgmgwuUzv1eFNjFNrJuPGZ/cQHW1aVrCdjO
# MqzBkq7yfp5sfw76OxSIacXzL2lW2oyXvLeD69tXyAUvSAncFA5xQ/DxBWKXbqOt1rWCDPScUbi46EZEIWKlJWfVkkPtpCKbspceEmntXdWVY6Yvi8X
# kMbe7a0bnzpnUAn6CRWDcTbkZv1Slhan/OVhmaf4dD8bavlHkSUJwHE1zSaR2Qhe+wzqDP4hlI2AkgWQDf8HQiKfGvN00SAzAp8VFvPMCuNKq7GEfli
# gFo07Q5W1Wp6WzmorRWazVk72ksvFJLUnRxLapKrSfKZVIR6IxMh7dP1L1xWBibOp2SqKPKEvLtJpKZn3wBf2Z0E8S4msXPSGPNt5H3vOxV14bCcp0d
# ghe90Szoj0VrG9hgtLjGsk6At3Zp7vfozaRT+4q+yJwSX5sA4XqfdALCVu7lRI2RdQJXNF1MiyMk7mUqKmSsm6lGpKqB9IpRJpKZSjNzFMVndqrlMZ+
# qtk2ImkzLYTaLl5x2mZklgq6xh4MpvFZEmjlMwUyVMioJIxxWnZLKZI6uWkUU7SWUwwt1fwL/mHdw0OH/GAws0J+vP37BevEfz0XduZ34/5grCEOmNV
# KKizFOY4JM2GTGBkOoHfAWuBAoSoKIEtoSXnqzTxHPeSWEWkdYeBm/PzIqNV1oFDiijrMEg9YuXVKbqqDQXqmE5QV4Q6eNAj7erSbWP+5qZt7OVK4Ap
# VYinngk3QOIW0rsD9PJ6y7GVG6DvjqYREZbUmhqwQeGiZWYwH9C27C/tpGjo5oejTy3ob2amUKOrTcypqzwl1qemqSI+rIATSB9BRIjKaXpiEJ7wvCX
# cpQJC/DUovvYyCUn4XFbqkhMqbuBeGEJ5Ii9+FtT8n1sv59W+UxX5mgjyVfZ0ZkxfJk75Wloa0pZcoelnCc8ryHm/HOUFoQJx2Q5cfj/jScXAO60ZsZ
# s5/WrQvIf8GTnjDfz7yf5/4v5nI4s7T+c9kEcZuljN6SISf78PQYV03fc7lleX4biD8JL1FlmJ9GvtVkKPD4Nav7AWQLisgvdN9PskWCcy8FymZ3STS
# 6CcmEi6LKpGf2ehwVYwMhVYAFR8CrrLunyvqkivqkivq5GzOzNpjL07SmZ3ecap1+D/D2TEBb/RVi8gsp+Q5hlrjDtu4PbWVqzdyT+YDs2CaVeZQbWO
# 25TyQ5gRjiAAyCfMD/GBGt8gxa5xxuLr2yYzItD5GieeT98copBUYNBuZKFh0/kN+VDMZhfAgMmviWZFZNkBMWo1pGURYzx+YTccEkfPIDaw2ufy5ev
# HY6ac6d9DGNYzWvD1onqRrJBb0HCZV1vvkpiY15EVMs1pPLXgpQ2v8qwVvyihez/o8lQysAgBUVo3pqpVpDKwmBVAm6VlJAdU32rMM6yiRUX8ib6FOB
# +o8vrfGXhL59oLNKsoiZ+FnqN2HMLhwkzCwg7Q1g2EBm/QbBhuQKjyC2honwJ6u6s+aJd6MtCB3DaT2NzRdDeXvAwDwDqEgQcM/04kuSxoS6ZWvgLHo
# m5floQxo+A2sQROj7UFQXjN3UOUxPbD+vPhIZNyBKqMOTbEJq7IPiDA0E7b1YBWiyhg0MGhRDYz8W63xxx77EDgKqM154D9ZZxr/It+XPzg5WkNvYpg
# bMcjjJu+nc5E/bMjYUzfCIKnAybxHuvgj114mUZgWVEOtU3914/DIs5MagxjnpNnmGqX6HOVzo9kxWI2DjDuKwyQ50xryTuk62DMzz4tlvq3ztoOmJZ
# +Ovwz8ZoW0V6K9jHKyV0nyMsrUQSlZmCMfA2I8xsSwcx3Sf00MsAOOZvNf1vGNoyaR/nqRgUTkTLv0wNKcrtgUqEzT844Duk5NLadIaVdunLqPkmKlA
# iK3ZxZc4zK15WX01E2kzBIw3SBZ0kdLJ6+5iW6NwmTpLbJ1t6LDBEFDlQpaE3jBvTXyTULVUW0rRLr5ZYKNqGS6kpe25lnlB5CXPwC7gbT6qyti6pAR
# PE8JMgclmQOpTGM5xF7YpKiyWFtpzMjYsMya8NqSjWirskvixKoGS0u1zgPPFswfVUrWMzJf7qqUUaJquvDbFMsQ7drit2h9mbn8ue/A957z4EFCcux
# RM02DT546odrp4k5ovoytt7NJ7uMj0syMdYVsIHX44PbUOq0voQ0lNE2WWVdlRFmRhq7K8EiIpoxIFHFy/NNkJHlaI8do5JBxo4EzbOSQV9vIai5P1x
# tZRrXAbDJfNMmMopv15YAqpV+jDGsUrZ5NeIM5qV6U8PaEBYkayayRzLqUWUhVqlupa6WilVpWqlitX7Vy1ZpVq1WtU7VC1dpIq3L82anUhlD0GqVXy
# 9WvUYb1kuvZqvUDUr2oai0pgjqpXhfJyyvVUCDqMmJPlr0vIw6lD5Lm16WgdGmxkmZbrrxINWXU0hs/mWvDUlI3S0ljUEr2jFLS1MrJg1KyXy55UE4O
# y8KaWn4wrLbNjqeTucZ+nNAfp+N55nNYF9QyQU0qOMgEhyaTI/+2iR1wsQOp2DATG3CxQbtY20PXggcBPRPQGwSMTMBoEOhlAr0GAYmm6SLF0ZxuSlp
# GMS1qBN2eQVKJ9gySSrVnkFRye0i09aoluQ8hGFlcNku0yM+fIvc8cDctPhNf1wxaipXKrWsUmdy6tkFrrInV11oEG/RUFzREQaNFsCcK1jFOwyDk3g
# Z8EN0cdmveNTVpzbumcq1519T3TJvMpye2A5PCRNyNgP6qtHEBXQ9MvtMRbBcVFjTnHbTwNLWNqbUwdbOFOSA24tHJRM4ctjEP2pjUmG3kAqJmrtGa1
# 5DnpS9Ll+ooZzVmaynSUNsfBzy6uHhC4MmE+De9TpbqzLSoR/K9MB9kfWKVzJaSwMBU6XSTE2rr9oTDl6yBk5CmK/a+0eCgURRe4Kay+hay8Po2le2p
# U/tx7Ka2FvU5Y9OsZu/ZWfv6plk3U+2GWt1QoRvqsvRQrf+cGmn6cNNsfBOFfn0nk0Kz0gWqIdurIFqvbaWKq0rNYqLMBhuNlVK32JosrzjBvkl9txg
# +zasq8s0yyde55MtZGRWUP12RCURv7NH5J6wYNTB7bcxBGxOGkxZuU17aH8l5w9acw3pOtnUmvKwm7TENNzSo6stZLyws0Bnl97hJ+VvkKvU/WzcY/T
# kNs+jo6PdazF3nsRdlVIu0KfaHl3ilbyhmXRycOgXKkjQZp8gfbV2hdbHWQk34YzYKV6uZ7fWW02aFPzDL6YMKX6sWqFVL0KpFiMso/JkUKphQE40O7
# 9MqiO0FrMkR3fKlhtJPPxl0Agk9OUn0VHUMC7jbFtITC+lLCzlYVxcwYNZI9JurO/YiPrpYOnvB1vkFSLC3bh1+GJNMjAG9+IH67JxmPefsytKG5C8q
# BBnk2Wfgbw5e7bQg8/kFfQjXFzU5IkWRv9pr9MeV1FwOeDGp1FWDzIHIE88vpbxss5HYqI1C6zI2PbR3YalurEXmxdpHr5UGBxLwv9KrzMw5C0qIzBa
# u2Z5TVvmyhBvrkbqByLRJpkVlIs5afu7ABMwGDdUkGgRa8vXaeG0PnE9No1Et1EmTCrWLfAjPNBEgG0uIAUKGEfIf3x9Mw75oMuZCpFuCsUbG0Skzp1
# O3LXA9giGX7doBUdtAwmJOFFqrJEwG1xaXCVVLFLwaf2UTVJMvbvTVZpkBlxm0yBxwmQO1zdut9hbKbnZtDm2NXULVUa/dMc74ELLYCQndaa/xh3J+P
# ScfvHo137F6IZnoUO5mRneXB7QFqmlIxivSmsfT3kZCJb+oYpeE7g4UWhh7v9EJQU7IzzkzYVi331i4XnK/RXibkvumpORTet7We3AFuBvJ5XMZYiVO
# f/utbxZ7E2tF9PUiRsV+LsSan7dOUt9Ysnj61dFx5kAicwgDJ+p7reJIVeSRO4CtySR1+JLmAYc+VeJjbImLrQad6VVWxGBaM5TlPJlrZffhoQUH/ol
# lal2OYEZctlLkHw83zI3yfJPOqMisie6uVVZXhJFfLsx701YhgWmqLcxKzr7asCjBd/vhkwLLHAyYn34Cf/yT+dxQhTXsvrgqqG5agtlUwsaqkspWNC
# WTEZ1jmnnNamIWAGw2cG9p68iOY9e3Ll37duX7FTNF5/Ziq5BWGBTtcoU7P109q1hKWg+8hdYUMcyBV4CaEnNZkLaCEI7FFW6WPFsvh9QoAKAamOyhE
# i54WZHmetC2ltciVf5Iy16lMl7VH5Q0Y2FZg6ZM+fDNJPuiZL9NciBKNpoEJV81ceWutLaXLY8W8yvhS29a3+IOJKVOQd9C1txctnn1qC4rWTuVPHyw
# iVT+2FYpM1sMuppD7w8dl5N54/RLPXJeZVFSFDDWCfTWCGTr8s0C5hoBo7UEuv5sqDPSdVs/r2yH1tIamBaxbgi2npqtfx1DT0tjypR727UFlASHqnX
# pPXJHpXztP+vE9UjfUDoD0pqj4riSc+jeavZMrVyVslypbLOanHpB1duLfnb9fPEpa+OkaZ9tIlNYmEJPtXGGZlzHpLtnYYemEBgj8r2Flz4N1/AFz8
# 8GAWOdQGEUTUaHZ9QdpuijL0ew8jq0JhC9hS//gLkkuBzdPSXeIqkkrciOU1VG1GREXUY0ZMSejGjKiH0ZMe+OL+zACZfVAyG1AyKlapSompSqS6mGl
# NqTUk0ptS+lDgrXsR4/5ygew8xoPQnNlNCGEpqmyoiig1uv0jtnFLNGGdYo5dIZSa/sZ/PFYNWihqh2HMaz2YV7IxPSNxEymoTyMk5CCMaWB4kR9zJl
# PAh9S4MvxjSiTz4flZPPtI9BZHux6xytgsXdUZQ+0mCzLfyZL7I/hCkQzy8KEimAWGRLaBcnx1YjRxU51mg8srLDJ5ZhweKdbs3PZ7AwP56dnOpRn3z
# 4RE89XazSh18vxSQxDy+fliKF9BS+nbrONcAXzuTQrufkqEaZ1Jo2Pck8Cn3fS4jiDm+IiXV4HcbpexY2piSbPY0qy03WlHUKQZa8oCZ1Zm8gRIs6+o
# XiKUk0nZiVHsUq5r2Vk0+NpUjn4tsXI5udb19Ke5UaDnU9t2rbFtdexYbSWhY8DFNcvLAu3NsNMvXU9kxSkOb2edY9p7VGmS6eVbN1mdtq+Jy8659bn
# gfKmxUNKnBfNActivP52IbyFl3Qfk4uYaDbKpv2vGz687IZz8vW2zpbq7w2VGmoTog3aD9SukX93P6oAlozk9ncF2TWN8u8SXut9wnys7KblVL/dtaU
# tlk39QWFrEcEk+8+X+KQronkxnzydzUyzFKyaJQkOb2AKTalqwfW9EJwvWBcvZVbzWv1eDyh5gJKIvyAsrV+JZ5bZFWFDqwNFuQb865fl29+rNjhbXD
# Q/GR2ueacentzJfnXN7KWIUqaf62XTebekvu0GNynpbomvdZBplbC9jlr/jSN5z6ajkCoomO6utGZhvXFw6l1enz20l7SCGyNjLJ3GeXVZEvOcSrbfa
# gXXOXIstWlK453zBO6XnaFI8tWlxbWr7MdJL5Dna0La7BirkWq2S5YPR4s7JyPDpu24Nt8E0aHmVS+xHcwtIaGNSADpsnLz710Vc0gfw1h806r5dNUw
# xoOYYFw64ymRdr2oL91Rk2DjEN124xiFUs5iLTeXrFNxE0q3t9QXKzEenEBeivQVlitIGrHaQ0xXBdpXISR49QG24lvJE1GCDI35y+U6EKXeOHBNtVV
# 7No+LC9+sUfdVsU1esNlEdUC288iqp1pcFuUReoT5TdvwNGND6GXuGwfqE4nj62wRpcj2rvCYY8WFt1g+hg8EGQtUrqqmRX2LY3oLEr0pRKXq8iN28R
# gKecyJR2OBOkd4Z3ZiRtP4DKsCnNCb3qynZELy81UkbAH6aXeg9siehSuAseOnyY04HJFsH7FSVGdMHTA+cdbsNUfJu8S6cuFpBQKG/YrK7w0vp+dv+
# f7eTmVx0U9sZ04ZPG5IZCXv4IFvUoBsCNKHkqFKixAzgoa2YHjOXbq1iVIV7+qFSrJeblaLt249rryEhr4rH7W0g6eEnir4BRjGr9U+WkYrhPxw9tJH
# IfxPAynRHQEUe9FnZGRS1DjmWYd+p/tp2Qer1xOgLAy9Du8cG8062o6kdCNBnqvSoeTU+8hlJPWyNGbOLLnC7xavg9hen5RJRKKDC8j1+ASGtREoIoL
# wDzN1ml5Ilv95clfcuaWC7jgGMZjZvXBjUPvqax91BhmI8NsYAwachAruMYYgqtqY3kCd9CWV1YyOHQzg7BEJIOoLiP2qkQ6oSFdNjH26sXkzF6VyZw
# qDR2waTJOr5HTr3PYrgjQDcsB76Wp/ahF/QaZQY2u6evzMpl6Xr2hTFNON5hXlUWaL0yRiyeabZL6xpK9jSX7G0sON5XsramRacXL8MGPuE9tzyxymm
# pVuidXYINe+61kazKf8uXEBm6/jTloYw7bmAc15lAO1IJZJHiDStTa11W5uFnSbau4trV4TxXfxRpxc7vSzW1KP9hYMVl/M3mvS3oWgSvpXcjcspq2L
# n+WkCx28kCkwjDSYyzLuWCtvycXKj6PYUNBZvMzzE2eQYVaJPQ2vjaUaUamTZh2EyhZXz+ITCEqaEmKPA5O9R+T10w/DhjmhbfZKG9uKd/fUn6wpfxw
# c3ky2Gq1wbbg6W08vYXXq/N68BYm7yvDNdBlzajaSmu5aPOREiWF1RqkpDh6yKYpu8BkLjJpyOI8CmJZuxJbm1GVaVCCHLe55ol9aS7Sn78f1GjQOGr
# kYV2HcLBFHByHNb5umTUanJORFGVa1SfSE6QAhnWN9mOlZySj7UAVP2LSCVLta7St6oVRSRiDnCE21Ml7NiLTAzY6/wkv3gvUKHshpXGWJfhH44BTLJ
# XtiWxTSGhqKdGaURMz6mJGU0gYwu+e8FuU6Qu/B+JvU/zdBmaoir9bJYUyD1Txd1uuAyHXyXFJvzQJb6ovvKiMXPRWHu2pPofkjQ6bpWp9mihzUJYht
# htJ5kcrKlm0alIKUdsIorb94/VqUvp4faPHm6WyBpXUttCGlZQM2HDrUg8qKVmpB9uVSnc1YO5MZt4CUZMQexKaKaH1JbSBjGbWaUOJ3FAidyCRO6jK
# MackcH4q+yWVWIJHU0YXvJ3O42svbeCJ+U5Gh2cWXT+bkhEMlvakjOwarzPeHRfvDpL9UlLskyv2QsVEqCwXVNYHIDmsJ+myOPV1Vi2T2unEmofO3iw
# EjTIEmtwoXxkrTdbzkT+Qr7epoLlGkP6pCpbVRJMbPaC36QPKqu2VNdYzS0lT4NIJimFY0zQfsARSr04aFiTq90PwVcaJGkdr5OhNnAOBUTgPclqTK+
# CZZtWmZLxkvS83IGqTtKotXRfgBQ42LZBGF2Uz9PXCed9oZXn0fvaznqm/DnI/h8BWuFohDNeVNtyiNENdKzz9CM7A73PTquwIS1eTyx1pRYAMJRX+S
# uOrcvTgAl9ko3MFYuAIBkfj+hvdQCaQVCGdl9hTG0vsqS0lDgsztrQQQLfDSw9j6YGYLjRalFhu2uVVzRq318rtt3F7qpxbs+7p5nu5JoaAXKBTRWaL
# mLm6QJfMFKW/K9L9LYRZszPLxP6GjzNLrZEmdbWcNISkUMGhlCxk7udzSU1KHAjEyrCakUyRNCiDGcifWiJn0iXndJLmo4vB1cxevVlqVFykvETKiaa
# M2K8Ri/Uuth8iKCInmBWC3q8QjF6NIMIsU6ulGbXS+tLMfWnmYY0gzTyUZe6pNYJUTK8RpGJVQi1dfpxkCVJk9GW0RuE6ID40yGhNpQwbSjFUGa2hFE
# NtKkWX0ZpK0ZtK6clodWG6z+PGJ5MaVVclJOv407hOroxjAkdacq9eslkn9euUutCgThrWSLqEIiGx/qPavTQLWPzeElHIMOsUmc5oBP+llBpVqT1jg
# wf3+hsI1RXYl75RGvV/KaXW0A1lr/hArVNqD4L9gaPp/LhGnMiI53WiRkP1/Fyl6pQqKzpjTZpZsscMK4RKewLDokaQPZ5QJ1Kq5KG6WSEYlXSVP6ik
# 2XUxiZwqQ5exJs0sCU64S1BCaviMOBP2XbSWpiqI9VrEwA9fl/SvQC/3u/Pz+WRqlVN6KWWUUlnnyaYzk/fg8qUNrGGVnO/Yq3kkpjNxEgSrQkPTGuj
# gnyfhmpTbl3Jz570qszBF8rR1/nOFZFTTxcJ47uLZg/+qRPP8Z7gZkvyt07/zJXMTCORB2VaAZaZhbvc9I/uQZK8//ZJkJ/+rtQqJLLFUQ9idAIP4oD
# HfdrmIvFonGpYhIUa0co2MmhJaFUheyvZ5zBxX89FPGVPw/BEPKAtJaxFGT/JLHo1Ids3j+ksEsmP7W10k0Jip7TKBxkxtFwo0Zmq7VECSqS0KdiYeD
# bSNImFvIq9vKS9Gcd5EviUq9ibZWyJjb5K9JTq2JPvmat9C41soews9bxoxe13WlqjZkqylEMgQHjnf7a1ESFUhWGd2kIr9yy7pFmS0DWT0DWTgWXBq
# pU6eNJAbS5SfYyidwDAq0XXyIBrZUfyhJL6e0Z6nZzQF2jOactb6VnWNYHvEMElwFuiva3G3DpjL0hbBu7Z8psG8a7IgDHTqWQ3qWLsMoyXXkOcabpW
# rCA65Ta6224ba8oHOBsLRqMHWuYdC7uHWuQ+E3Adb52461dUYZOxJE26h9KCZNYXkql6C2BiMJ2tKQkCepk95o+NI1VIJl8ySNz2TtFXu2sGkbXLXTy
# dtkVusdj3b+nNKG+cRDittmkesWHuedYeC8lFs83NERZZnnCUKIv1ZuXryI0NwHOgsOxtUPjC0ScjszYsQosSRr/t0Bv17KchQlaE1MfQmhtHE6DUxx
# LiMahOsCkdr5OiNHKOR02vkCNgOCLlfhVUQNRlRlxENGbEnI5pigE0CqvaucqImI+oyoiEj9mREU3b8waQbNv2GwxFm1Reizm08lGFW/RokXMmhEeg8
# tLJ3QXHOQm1m6c0sOLLRzOo1sAaNrPJSULuIvpGIvkakoQbC0N5w+sJsOH0hOavA3krmQE7k2o82lMV1dTvx7Uo3tisduu5txPvrzmYIZzGKAxoXy/M
# HP5KfzTC39OxnW7+Ch52QUadhFUXHtNYTBK3iLc8Z0rMEeU11tdnbXy6ebcQ3KEaSg8c2LZ0iyNtfjXNeP3KQOVf3mQMfe62Zz8Ow6QiAxPE/d7VuOx
# 3AhBrPB0gORZQ89sueh81O/fX20yhV9lhck7O/rnzpQAC8rdTcY47fB7LHmC28gwZ37sYWwbh5pqo/LWwmXLqLMHAkTou5m+t6oYoDrSH3mO2J/qG6K
# qb6Yoqw1JpD5ZF7E8ZuyTlyncthowsg+cr6bMDReDhX6u6zibipZt56oni/6oCn896z6oVX0HsN9Lo/Hjy20SWvYGptTL2FmW9Ogh+e5BXXffAKh6E2
# /7Oqs5q5gbPaRsKZL1qjZ1vNWa1emsQTTGv2BNPWeoL1pZ5gEuelzOYoHraGP5S5TzVmN8xWdr/94cNmNhsYxHUSfiprrYhZ9bkqa6XsYVXmiW5WjRy
# 9kWM2cgZlzkCCa9CCq+yIJfJK3ldmm/dVeZDJ+poDk0aJNi1dsIM4iRXJbhs8/jQ2IrXskFWM/hkh7/gb+2/GaPjyC9cumeNSWb2Fk5fcyUlG7VcdqZ
# o8icDdSZMy+k2MYZ1RuOwUqhM5cm+gXju9cjCjgX8g8edpKHcop2fdwhp/HHOdP05D9Q1T+lTma2Nu4mtjrvO1aXhygx4OmuQPJPLlgURr5BpqnQvfy
# bjmNCMVhC24JkeacZMbzVjuRKNLH9CTUk0JwL5UciijSkUH9TIHMjlpiQciMfP+0EpffuEq0od5+dBqZJqNTOZk0swcVmf8FU8T1Rqo5cnVQG2UZ74n
# pihP03L5vJ+WdtI1f5S6swlbvJfSo9w3ZJ2zyf+RzKT/Tt0gTb57p/ztH98tfLjS653y3YfVMno6jGObOitEWTggYK28gN8D4AUBsXOTOzsCxt+guMi
# O7aVLY8m8U/7xnWU54cKyIFu8Ct7S4GnpU+QGRKgoy0q/+xdhEAt9ad27T4QRrHyfkF4UkL9aekGYeOnTkR8u7l8QXL+3NTgX4jS99WWQ+r0vhHTjh/
# ZzFBbd1VREi/pzwKSvB0uysH07VpLVUglvlMkrQhbbn5XFXaLMjpXpZK68qjdYxfY61fby7/aZ3deh43gQ1cz2FT/8vB+lym9umigEhQIxQvc1qtXY3
# V+EcewushsNntfBnXlJen5zk7hpXoeQJinXYx0cH0oo0D/67cgRtqiHKENZ2OnibkkgKXbs2ntUNz9NRon0Hf7t/75FNbip3aHaavs74FOxn6yu09he
# pK6jwKccpbtvd/iPDmmjqbf/Rmub7uz+12/u4pi89zDe+f5jwDs+1/n++W/9j++3E99bLl1n4hNocRgkig1hAJRrO/EWSuL6rKtWdkiH/qNiKrtd6rQ
# d109thfRZys7laI/oYlf57KV3SsIDQXekKX8gXRgxPSDYquLRE+/QIkATXqDYCtPShUIwu2CUqG8MpiaXtymFth3DVN67V91T2wmq7TlqgwHzHvX2J+
# lNWSXEWCH5TiaTmXI67pAenccnZSfv5kmPH6fKDWzcKrOrPVDJYtkxbayChRunNhnonzqogN+xNYjK6HRjoDcxQueZ3rlkOs/uZiQdpUtjzr9deoFnh
# 1mySxPdtxPrcqTsK9rbCMK8d2lFg75rxYWI9nnLYCHt99lYvAiX115gy1a8cKXnG6ntiQLXuiqTDlXZGCveMrIXqZLLdHx0hDv74EHKMoRVXrZED/2B
# 70YpN8WV2E0iYm8raci7ijBxE7pYzldessVCL7gVMndRjcUkhrSkJSyek6EWFLVDhpn0Alj72p4S3ZAcp0mo9izbJ1PtGyUIRfEurbEu4fkdqi4xuGB
# XLK41mT3ygaW2n9nuxFaDxfe78L8mh8rso1JsQiW7qC+qL35VEZgrURgA5O7oZXp1qJAeRDkdK1caaS1h7Has9kHY7fpntdc7/va7V39pd6g4Fz+ob4
# zyKNL54aNdVV0eQDq2t239Y/6vLs1IDrKZXAK3XvLlnT1YAVysaABwNre7ISUp5qNJvpLbbq32JN7t0rZO3dSG/1Fb2y+dwPaCd+Mt7GDhdnwdZT4/U
# cAq4csmxCx5hTbJ5t422y+d0g1Zb8FH1Gq9ucPNt1jzxSrdv7Zh65m89GPb97UBmKQ76rsb2/P3FO0dXGi8p+jvfDgFs6cY75au462We0rvXQrRjHa7
# ri0NtSXXlhc47mM2MhEk4cKjYxFdUNzX2Lph4HZJJbPxe2KtO1QdZPghyrh+ouqhxz3IuEywJmm84i6AQZiCwHSkEFp6h43HUVj8pq62Hxo/jo9SyiL
# 2iIxnQ/8DioD+x0veJzeXi5n3yG4hH5H2ROpI4EOvRLmjVC7QJT1ekf4bZs2xm0Bvfu2lSztSdqZeMEtHq3SPqGniu5ejSWpPV37qXdgBUVXOgDCPp8
# Gl6zoCbXbnnQZF+piAILb2JdjppyBP/i+47H56b3H+4MaT6YRuaV/SNfNCZnIaEG7i0ojDM54o2BeuPzs+TcJqNvJGQZJ0IBC9rKBPPdLnBLcnXpoQ4
# i4ZnKDeiUJmDAoZ2PDtv/Tb/0TmYJd2WhOa6I8mbQfkd02m3FDOvMC144J7Zfsrd2pHpBlc3AnverIk+cZalTx+fGpqD1lG0pjGMXkFAWsj2qtuI9dh
# 6L/Qggt5ODhu8i9JeeCBAMXaw9O/waoXRm6DK+o3Wu/cK9ej5/4WduB4DrE5XlX14fDH8GXqH6yW1y71qFqynkGhz1DuSAcgO4My/CY//PLG5KcZi8z
# RgeZfrfhBNytOJ+6k+h2qvLgT3bEGX676QVer3sFGX2y/d7SP17vax+vd7uP17vbxenf7+Ffa6F9wOvPe9oJ8W9wFL5n4KUlt/wumMn/EexQhHtmOMh
# kdnrGDTcqNb98qO6vIoQvdj+AG5ROl78re2J8YuABuRzr8n+Ge4r1x3yj2/VC5sYXYM9fs/gbFDmz/KfESjDnTuZgzI+h7SJdznZIG7XjJAp4c2GkYd
# 0gJSnQzoufQXOc0AJcc8lAWLdWOn67cOHUfQUX7NR0pO/a9rYwur670Lrk6wt0yLF7hL8oOnKrYd1zq9UkdmHYrOoKv6mTn1939H6+vlYdE+Xk07qiu
# Km2HnsQpKc8Lg13U17Pa1mIBusr0hg1sowaGSntWK8MebLsG1j19EZNAuf4L6b+7bFadeLe3CZzlPToCPdy6cWdVMa12MQq0En5/HpmlZfo52f+x93f
# +yaCy1isrt5BQWWuUlYYRqmozVX1CRW2mqF/f4ie4rbpyiwjVtU5d2La2UBYqauOP8O2tD4GneevyqZ/2jW8/hCs0ULdQH+vJUH3ZnE9ioO5cX+8tFn
# u9v+/CpQSd1wfpn7hGyF97YXpHcqJmuGaYOpQHcBPvvD5wtvIdzk22UEvnzZ9uRZTsWCS3UXY5hpKEN6nixKR3BBWwUBGzj7PZaZdiueus3tekzf+gd
# aniRkcr3rXLcboUHFvZV9gtQLBRdEtG9GsIC01+0zug5l36vJPV9W9umnqBS7r2HU2xH71ORVCrKEDvugKMriug9xoV8IKH3WFCczqmzsUJHObW4Hwr
# cwbfsf3P9lOi3Ng+SXmBoqvaQEk8CIjlEZMwdBMFQpC4j+CGvAe5dchNI9nQpJEnz9zoSnJGugsRSljcMNbKulj/hHq1frkC/niP9WMPbkdNUjt1ydD
# veCx8JgshkyguKT9lIXjg0sikcxftXYBJJMTWAS0ojvfgOUwrPNaOm+q46IGzIJwFfWVXJ0lvdbDpNXT0SjqY94erVBmdXHbGGsoHrUq396qGLfbCCD
# J6nVHjBbE7O1H6o6n8538SQ+462Ymc21NnV/nhB0XTlH/+U6nQjN1doNIrBzV1t5rtr4pmZrlIFwgE/Y1JxYDkPD4BSX2j55TfGUGjJe1EN6dZMxtfq
# MbO7hsenZoFMIJziH9VKFiCgJRtMjRrc72l4uS5BL5NrAweolQWj+ebHq/xjkS8IhANlg0vD6DW7RHExcZ7A/DeADR48a4lvJvqm7qb6iVnCCXjGxTg
# JspNHC6JcdGxSNWeAzMlHguxO7E/swvdlTvv9k6JVrGXPnUkaIx3o1TaP1GD/XrDYf47NSH0BLbih2S2QenP1ceLxmfJg7P0yLsDAizyMEcPiEWi2FH
# ke66z17S0wFYJzF0M3oLBWzB4CwZvwePpWyoC7Odlt78hUMUxP8ID7eIvvhth48g0whpIl7WRTTEnLO760r4N3JSYIewyDOWYXsneqVvqMo2wzY8OK6
# JbS9qj1tfOrHaIYvnT5GKk3MbhKlIc98YLvI61ipnnu6TuqC48zyKr7qrTXaa2vwMa2E9W17AsAcsW1Nk93X27w390SBuBuyJa8NG2qGmk87YFbgB+s
# 5X9eWXH93Bo9z0Ek1B87971vbswdDo7x8KTUMKXIOzzskjl+7Dk67KeMHZv4TrAbvWFpMYKOMTnqsluimeqea06+fcd6ljCfgBchZZdDtfh8x1d1gUe
# ovo3f29f6JP9zXxrHdPDh/wOSiJDJmw++XjIJwXLOd06XFdcxpn1tp1XBD2j100lzDx/FeUD0MucVdnG0CxvavmprexMJ/NHaxk6+/BjV/lId82JPGz
# wMAv7YyS1Iv9k0E8Z6KdXD/rxEToD6p0CnwO4q4QPduzZYGqQESP2Hl8R2KevCOzT1wS2aQHrzwGTvh4s5COmB4K8G28Bb+71IAOPczuGoJTQviYvoL
# Mvcxmc0qG1zRfQoKf8IgLEdXa+H63SI7gh/tQ5gznQ9+wsH2dehjdpIVDnTR/sKrkQf++H17Z/QiZDs7RJZh7fZwK7u3gIsLOHAIk2VuQzj1ObvPMnP
# AXZ9SOhnW4M3XKZMcaKt4zsRarkMh1v/xfZIa5lCHYsszRgpswPzNOOInaTiAzrsP8DrIVPBu+E3t3KB//MewCWnorMXVRjKWgGXY4jk0JQ1I72Nkov
# gLWv7SnRDclxmoRqz7J9X/FuFHp9WS6+iw5HeNwUj5t+5cdNMaIBRjT4GjXTw/aDbl8dqOwkjsM4M3ipI7D0aO637v2cuLd0DRt6QdILXHu+5OR6x2a
# F4oJwaYrYIb3QCx7gWO/pmFijYdylq4Dm0BG48f41rB03mxDUIfCOriqTMTO+h8hz6SpwZ53qSedQ40JJEeiCKeFtp/RwFsKBCTaSdPGbmZ/Q7oIvHb
# 1ODbyguwVzufEWfFrRRT80MKSEEKl04WtfY+tbgbvbTQckvqwH8cRh+sTWVB33xl75EDDk2iNWJ9szzSyx/2SGaDf15dtPcPkg99hK2UDcsRBai9ChH
# xKxQllMdVCF+wBtIwZXzySNV3yfHZyEicB0RFS1Su+61Gbm9L5X1tsqi9gjMqCSVQL7EBFJxRAGmPsAHrlJSq06ZUd9d2N7/p6ivwMvgS5p7LShoz6+
# vOBh+1+bMsAxY/gyygC7fT+aK4tVyu18YrLsaMoPWafDI7nNSUshxFvqY1LQPt95izvSTS38leMm1TxSD5PhNxn4zgvm3tKdMqu3I3HeqI3vJVmjkPn
# bf+M172Bwv6zq2afewbfODi91qOLi4LCnLF3HWy2VT7Mu1z6KwyWxq16ZEl7QUJh6gQc3UcBJCojjCVvSh+dj7u0K0fu0H7gMdWwl9kKWnlKV7SlGRp
# iz83u9LH3lxk+U9uoMhpdUKJn5QuVPnRaFcplCo5zAVNopdT3Y7W3vwS609GALbe7B7lzbmh2v+1SpBHx3udIohacMlsqU2GNJ/tmaRWZO6ReU1/spv
# 9wAQfeIxFGiIwOjsDfWSVOAnjvvkAkwv+e9Cuk/6O+876Cprn3289i7vXVjfpDnCz6CFzubNOO3dbadTjKVTp0DorsM2eLfwva965gu/rFQNm9hqLTD
# LNmlMxDszK4regPxE73MiOhkkJ9unQw5UcIH8ron6Hf/rVa3o45MYrX3lGPb97WBcqVFGro6l13l2Umnrp+22NJfHtXWSTdx6x/zf3XpdN9BZhYmq8i
# NuW24Bzb0YsXueqKfwQ0pSTEfTTAYu2UsJt7t0rZOic0I/38D2kI3wRdeQoIIhks72lP0/7ejvvPZaor2bsmXXfV3qXRJpWvayQ02VNRab9Ms5F1XXU
# 7RCxd9KZ+tqSvS6YBZDwtdoCba/yg7Uy+YQVimvdldeDmapDbdhb2wg1s3o3rBre/Ow89ufGI75w9uPFly1jF5KhngL8E4OCV54X/OOgye6L7ZJ2IJT
# A6lxMPA+XllO5ewUhncNuXbBec8gjZRiK0BO1HduXAWnFeLTu9BEgH4W71kNSmZlgqYnGBSeoFybZP5p6/Yi4UbpbJobt1TiRs4C/Ipd04lfOXr02yo
# dq3GB12p8Z1N+n3vkXzxies6XdmMfm+TzzqbY7uwHhc/Jantf8H+MwYc/ZbCeuIr68wri+9Cfrm874NP/ijzyU/2lBVY8u6b2zftF5K/MtwU7IJ0tXD
# vGFsb/EqqQhpJqKQwE+KHPP9JzLB/Kn9V9DemWAX31l4ubVLrEbfW8p2W11gpvufzjbyj7EK7cnXa3hZUBrILW1v0yo1wmUdJzN9f8mpCNP9GrBeliE
# tfepWLouJZzBffZTqAR9vxE5lNwmX1yg7LsrP7Hz+oEMo5ejjk60qksmR2DpFidnZ//MEEJstz4d7s7L4hFd3Z/eEHtVMOVt1ymcHQWBtW9sXtEeqMD
# OFXH8jnSJd7IQRLlP6ovVYLSoZYAcjKj5r6NYFmmPWvDfKP5h+P+HnjVBH3YQv1bjyG/Clw6y34deM1XwLul3lv/0RGgsP/Ge4p3hv3jWLfD5Ubmwac
# ZpbndRgmsLNlB7b/lHhJl4yMEazyXenKdWrfdvaCWiW6GYXLay9wnVN6+xJ56CW9A8+m57CIHQoq2q/pSNmx721ldHl1pXfJP23suhGptHL9l+trpcs
# Np1smesdcvD/o/Bpi8pZ/6JKD8wejoxXHOSjeQd+BzztZXRPbNyXmTpJAhCr70euUe31FAXrXFWB0XQG9L1TAi01c5/aq/cyxNoSl8tRenY53vnfchf
# 00DR332AscL7j94H4eT5Pvd+mtiVzmmoWpyKc72VbDOLuaYRTGsXHipQm7+DDPdkXz5fJk2hivAv1BGx+FvjOefj6b66pmbpwpAGwk08YZnAvVyJ5Uz
# bQe2/Y5SG0GD/rm+bIKbZtPrFdDXpYZJl2kPTCZSLu6JA24a3dPZltO7Tuc3+jdgtY/Hp/+RUPaurbDosbVLlTLL50TL2XslpJ+Rx3hokWptsUlhLZD
# 7xSEZrEHwZzI6Er6WaVzO61rNdK1mbBUIYrjPXgOP+UBSklxse9brW7myLPD4lbvdtLE6NZXzze1Ix7aKVylCfnaqTlAGgKB6uJi4DdaWc93V5Hggte
# huh8GqbefH/OC3d/yjuZVn66Ikq8hWqWd3dj7Ai0pO2SKPuzShOL6qbY24baoxykLd1xT4DqDutpMV8sVqkq6LMZXc4UYS3jX7sZK2eMBqbr1cbWtYb
# ePbeTzQlVlS/btqjJRUZspavCgoao2VRV+fqVds69NXRgM7CU2frK97x2M0dTpGE0bzNwXREe3YfyEWpFppWH94hu+uXG9ct6xCFbJvQL3OV5ltzWQ3
# /xnj/zM7ngZkt/8OhetD+I00aE7czZobKyNoVq3Viu9Oa+iTuOdUtakoMhXqaSXi+DT4An3/W5HIhit8QTsSkgj6Yr06Vj5HMb39DbnkDw7qa8ZVjqk
# K7FLyhM9oa8aFl8b7ZTyy9L0orfq9/LeikjpQ1pW1zqvhpVvfCev650sV894JRuO2x3SbOvialXB+TJFtaWLDV1QrNDMMx3Tds5bM23mV6V2foX6F1b
# XpPo3/whjNFM+6nutvmHBF9v7n6l/7G/+Dfp3LtTI+EpfwkvETbM/c9fa6WSuvKr4kBVo6WtE9vJxI595XK1LZ5A65SmJMei+9VMPwq7RmSaNe90lFS
# RZ1B9UhqN8f6Z/zyKC79DAWSfEjrl2SZkuG4+IMfN2dtyd3XViw/Gt1vD6N3eRvlM0sNkm+UVBM4gdP7XTxR1Ee31L4/LCjSJgnLEbpEWZfbhjoySoG
# WDerSD6rWaCcWev9qhZ+JMLZh35cWyn9DeUSOwUYviRHydzPjk9mXdp7zsJN+u/vuVLvqibR+fV4D6S/ohd21NWhRdAOXRm9o5+SCPbD0+dM2sO/Rf8
# IDO3qzP2PWmusvNpRmdNu+yDYhQ69dplcy+4kMi3o2PPh5gMs2P2hcKXqbt8Fqa5+9pyxWdhkEipDF1jNmBmZzJxJmVqPI8OKU3Vs+eSd3WmjcPVte9
# O3luHH8YkyS5Hmrw/j3dp4MI1Pc9/0yrP43uoZFZL8ptVTloVAElxsTrBL1ap5Wpfc7NKQUKsFYjxanE5Wi2Q012KFDq1/y72JkfsHD/FoudTWpHay+
# a2IjFfdSM98fn55Sg7u8XhnswuOdyEKmofDm3+BY5u/oX2lRS84+0L0F2WYOAJXJpi7+Tq6PgvTJjWgKiHVYDQlUUcJsn+wnftIIuGTa/SA19jpkoWt
# NxN/1v5gu8QJ2pf0iv8qkRh4lHHb9IrhGTcjksByb0F3GrgPi78FTvzSwb2JdyFMrt6TcGZKaRKIPUiDqvj3sYuHQFuyL9OuHw96xYy4PkbeVQWYRg7
# 4MLgfiWQn74+yL9/NZBj11kt4DKBO09/3UiTBZkA8VDCsBIXpTp8fsXlCGxykLyWkNjsQvqixxBuqSRgqx3ia4w1fRuGzhrYb4rIWO/+w0uO7XsXol4
# FDsn+IzEmyG/7Otn5fVf5KzFSaDr7SN5c3IWU+oriVndpmKa+SorvBrfpHYvL06V4RWLlIfKAd+MtZLcqfsM60MdKp9tAtf4dbQZ0WxTscBvmblms/k
# WY7ETW5ZXyX8oO+XufGOe7u8rrUssLbiwn3jLyXYXONEE3dKM4u1opjOHuhTTk90YlHdpwR72gXlAvHdfLiw5H4oSUD0bk51uYUeD+P8a8+yZi3lVWE
# ZN1y4jo9YHuS19XiL/cnYMv3v2SL/vsdW6eWVPG/6IyCmX8+ocp4484+CdCncfe7a0bv73x7VvY5JYd4kNUiApRISpEhagQFaJCVIgKUSEqRIWoEBWi
# QlSIClEhKkSFqBAVokJUiApRISpEhagQFaJCVIgKUSEqRIWoEBWiQlSIClEhKkSFqBAVokJUiApRISpEhagQFaJCVIgKUSEqRIWoEBWiQlSIClEhKkS
# FqBAVokJUiApRISpEhagQFaJCVIgKUSEqRIWoEBWiQlSIClEhKkSFqBAVokJUiApRISpEhagQFaJCVIgKUSEqRIWoEBWiQlSIClEhKkSFqBAVokJUiA
# pRISpEhagQFaJCVIgKUSEqRIWoEBWiQlSIClEhKkSFqBAVokJUiApRISpEhagQFaJCVIgKUSEqRIWoEBWiQlSIClEhKkSFqBAVokJUiApRISpEhagQF
# aJCVIgKUSEqRIWoEBWiQlSIClEhKkSFqBAVokJUiApRISpEhagQFaJCVIgKUSEqRIWoEBWiQlSIClEhKkSFqBAVokJUiApRISpEhagQFaJCVIgKUSEq
# RIWoEBWiQlSIClEhKkSFqBAVokJUiApRISpEhagQFaJCVIgKUSEqRIWoEBWiQlSIClEhKkSFqBAVokJUiApRISpEhagQFaJCVIgKUSEqRIWoEBWiQlS
# IClEhKkSFqBAVokJUiApRISpEhagQFaJCVIgKUSEqRIWoEBWiQlSIClEhKkSFqBAVokJUiApRISpEhagQFaJCVIgKUSEqRIWoEBWiQlSIClEhKkSFqB
# AVokJUiApRISpEhagQFaJCVIgKUSEqRIWoEBWiQlSIClEhKkSFqBAVokJUiApRISpEhagQFaJCVIgKUSEqRIWoEBWiQlSIClEhKkSFqBAVokJUiApRI
# SpEhagQFaJCVIgKUSEqRIWoEBWiQlSIClEhKkSFqBAVokJUiApRISpEhagQFaJCVIgKUSEqRIWoEBWiQlSIClEhKkSFqBAVokJUiApRISpEhagQFaJC
# VIgKUSEqRIWoEBWiQlSIClEhKkSFqBAVokJUiApRISpEhagQFaJCVIgKUSEqRIWoEBWiQlSIClEhKkSFqBAVokJUiApRISpEhagQFaJCVIgKUSEqRIW
# oEBWiQlSIClEhKkSFqBAVokJUiApRISpEhagQFaJCVIgKUSEqRIWoEBWiQlSIClEhKkSFqBAVokJUiApRISpEhagQFaJCVIgKUSEqRIWoEBWiQlSICl
# EhKkSFqBAVokJUiApRISpEhagQFaJCVIgKUSEqRIWoEBWiQlSIClEhKkSFqBAVokJUiApRISpEhagQFaJCVIgKUSEqRIWoEBWiQlSIClEhKkSFqBAVo
# kJUiApRISpEhagQFaJCVIgKUSEqRIWoEBWiQlSIClEhKkSFqBAVokJUiApRISpEhagQFaJCVIgKUSEqRIWoEBWiQlSIClEhKkSFqBAVokJUiApRISpE
# hagQFaJCVIgKUSEqRIWoEBWiQlSIClEhKkSFqBAVokJUiApRISpEhagQFaJCVIgKUSEqRIWoEBWiQlSIClEhKkSFqBAVokJUiApRISpEhagQFaJCVIg
# KUVVQtRc7eXCDNJFm/P8BT0UcawcFAA=='
#     }
# }
# Inaccessible files
# {
#     'ZJets': {},
#     'Data': {
#         'nano_dimuon_not_there.root': CoffeaROOTFileSpecOptional(
#             object_path='Events',
#             steps=None,
#             num_entries=None,
#             format='root',
#             uuid=None,
#             num_selected_entries=None
#         )
#     }
# }

# %% [markdown]
# ## 6. Integration with apply_to_fileset
#
# The `apply_to_fileset` function processes datasets using FileSpec classes:

# %%
# 6.1 Example processor for demonstration
to_compute = apply_to_fileset(
    NanoEventsProcessor(),
    dataset_runnable,
    schemaclass=NanoAODSchema,
)
out = dask.compute(to_compute)[0]
rich.print(out)
# Out:
# /Users/nmangane/scikit-hep-dev-4/coffea/src/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_electronIdx => Electron
#   warnings.warn(
# /Users/nmangane/scikit-hep-dev-4/coffea/src/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_genPartIdx => GenPart
#   warnings.warn(
# /Users/nmangane/scikit-hep-dev-4/coffea/src/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_photonIdx => Photon
#   warnings.warn(
# /Users/nmangane/scikit-hep-dev-4/coffea/src/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for FatJet_genJetAK8Idx => GenJetAK8
#   warnings.warn(
# {
#     'ZJets': {
#         'mass': Hist(
#   StrCategory(['ZJets'], growth=True, name='dataset', label='Primary dataset'),
#   Regular(30000, 0.25, 300, name='mass', label='$m_{\\mu\\mu}$ [GeV]'),
#   storage=Double()) # Sum: 6.0,
#         'pt': Hist(
#   StrCategory(['ZJets'], growth=True, name='dataset', label='Primary dataset'),
#   Regular(30000, 0.24, 300, name='pt', label='$p_{T}$ [GeV]'),
#   storage=Double()) # Sum: 18.0,
#         'cutflow': {'ZJets_pt': np.int64(18), 'ZJets_mass': np.int64(6)},
#         'worker': set()
#     },
#     'Data': {
#         'mass': Hist(
#   StrCategory(['Data'], growth=True, name='dataset', label='Primary dataset'),
#   Regular(30000, 0.25, 300, name='mass', label='$m_{\\mu\\mu}$ [GeV]'),
#   storage=Double()) # Sum: 66.0,
#         'pt': Hist(
#   StrCategory(['Data'], growth=True, name='dataset', label='Primary dataset'),
#   Regular(30000, 0.24, 300, name='pt', label='$p_{T}$ [GeV]'),
#   storage=Double()) # Sum: 84.0,
#         'cutflow': {'Data_pt': np.int64(84), 'Data_mass': np.int64(66)},
#         'worker': set()
#     }
# }

# %% [markdown]
# ## 7. Dataset Manipulation Functions
#
# Coffea provides powerful functions for manipulating FileSpec-based datasets:
#
# - **max_chunks**: Limit processing to first N chunks per dataset
# - **max_chunks_per_file**: Limit processing to first N chunks per file
# - **slice_chunks**: Select specific chunk ranges
# - **max_files**: Limit number of files per dataset
# - **slice_files**: Select specific file ranges
# - **filter_files**: Remove files based on criteria

# %%
# 7.1 Chunk-based manipulations
print("=== Chunk-based Manipulations ===")

# Create a sample fileset for demonstration
sample_fileset = FilesetSpec({
    "large_dataset": DatasetSpec(
        files={
            f"file_{i}.root": CoffeaROOTFileSpec(
                object_path="Events",
                steps=[[j*1000, (j+1)*1000] for j in range(10)],  # 10 chunks per file
                num_entries=10000,
                uuid=f"uuid-{i}"
            )
            for i in range(3)  # 3 files
        },
        metadata={"total_files": 3}
    )
})

print(f"Original dataset: {len(sample_fileset['large_dataset'].files)} files")

# Limit to first 5 chunks total per dataset
limited_chunks = max_chunks(sample_fileset, maxchunks=5)
print("After max_chunks(5):")
total_chunks = sum(len(f.steps) for f in limited_chunks['large_dataset'].files.values())
print(f"  Total chunks: {total_chunks}")

# Limit to first 2 chunks per file
limited_per_file = max_chunks_per_file(sample_fileset, maxchunks=2)
print("After max_chunks_per_file(2):")
for fname, fspec in limited_per_file['large_dataset'].files.items():
    print(f"  {fname}: {len(fspec.steps)} chunks")
# Out:
# === Chunk-based Manipulations ===
# Original dataset: 3 files
# After max_chunks(5):
#   Total chunks: 5
# After max_chunks_per_file(2):
#   file_0.root: 2 chunks
#   file_1.root: 2 chunks
#   file_2.root: 2 chunks

# %%
# 7.2 Advanced chunk slicing
print("=== Advanced Chunk Slicing ===")

# Slice specific chunk ranges
middle_chunks = slice_chunks(sample_fileset, slice(5, 15))
print("Middle chunks (5:15):")
total_chunks = sum(len(f.steps) for f in middle_chunks['large_dataset'].files.values())
print(f"  Total chunks: {total_chunks}")

# Slice every other chunk
every_other = slice_chunks(sample_fileset, slice(None, None, 2))
print("Every other chunk (::2):")
total_chunks = sum(len(f.steps) for f in every_other['large_dataset'].files.values())
print(f"  Total chunks: {total_chunks}")

# Slice per file vs per dataset
per_file_slice = slice_chunks(sample_fileset, slice(3), bydataset=False)
print("First 3 chunks per file:")
for fname, fspec in per_file_slice['large_dataset'].files.items():
    print(f"  {fname}: {len(fspec.steps)} chunks")
# Out:
# === Advanced Chunk Slicing ===
# Middle chunks (5:15):
#   Total chunks: 10
# Every other chunk (::2):
#   Total chunks: 15
# First 3 chunks per file:
#   file_0.root: 3 chunks
#   file_1.root: 3 chunks
#   file_2.root: 3 chunks

# %%
# 7.3 File-based manipulations
print("=== File-based Manipulations ===")

# Limit number of files
limited_files = max_files(sample_fileset, maxfiles=2)
print(f"After max_files(2): {len(limited_files['large_dataset'].files)} files")

# Slice specific files
first_two_files = slice_files(sample_fileset, slice(2))
print(f"First two files: {len(first_two_files['large_dataset'].files)} files")
print(f"File names: {list(first_two_files['large_dataset'].files.keys())}")

# Last file only
last_file = slice_files(sample_fileset, slice(-1, None))
print(f"Last file: {list(last_file['large_dataset'].files.keys())}")
# Out:
# === File-based Manipulations ===
# After max_files(2): 2 files
# First two files: 2 files
# File names: ['file_0.root', 'file_1.root']
# Last file: ['file_2.root']

# %%
# 7.4 Filtering files
print("=== File Filtering ===")

# Create a sample with some empty files for filtering
fileset_with_empty = FilesetSpec({
    "mixed_dataset": DatasetSpec(
        files={
            "good_file_1.root": CoffeaROOTFileSpec(
                object_path="Events",
                steps=[[0, 1000]],
                num_entries=1000,
                uuid="good-1"
            ),
            "empty_file.root": CoffeaROOTFileSpec(
                object_path="Events", 
                steps=[[0, 0]],  # Empty file
                num_entries=0,
                uuid="empty"
            ),
            "good_file_2.root": CoffeaROOTFileSpec(
                object_path="Events",
                steps=[[0, 2000]],
                num_entries=2000,
                uuid="good-2"
            )
        }
    )
})

print(f"Before filtering: {len(fileset_with_empty['mixed_dataset'].files)} files")

# Filter out empty files
filtered_fileset = filter_files(fileset_with_empty)
print(f"After filtering: {len(filtered_fileset['mixed_dataset'].files)} files")
print(f"Remaining files: {list(filtered_fileset['mixed_dataset'].files.keys())}")
# Out:
# === File Filtering ===
# Before filtering: 3 files
# After filtering: 2 files
# Remaining files: ['good_file_1.root', 'good_file_2.root']

# %% [markdown]
# ## 8. Advanced Usage Examples
#
# This section demonstrates advanced patterns and best practices for using FileSpec classes in real-world scenarios.

# %%
# 8.1 Building complex analysis filesets
print("=== Complex Analysis Fileset ===")

def build_analysis_fileset():
    """Build a comprehensive analysis fileset"""
    
    # Signal samples
    signal_samples = {}
    for mass in [125, 200, 300]:
        signal_samples[f"higgs_m{mass}"] = DatasetSpec(
            files={
                f"higgs_m{mass}_part{i}.root": CoffeaROOTFileSpec(
                    object_path="Events",
                    steps=[[j*5000, (j+1)*5000] for j in range(20)],
                    num_entries=100000,
                    uuid=f"higgs-{mass}-{i}"
                )
                for i in range(3)
            },
            metadata={
                "process": "higgs",
                "mass": mass,
                "cross_section": 48.58 if mass == 125 else 10.0,
                "is_signal": True
            }
        )
    
    # Background samples
    background_samples = {
        "ttbar": DatasetSpec(
            files={
                f"ttbar_part{i}.root": "Events" for i in range(10)
            },
            metadata={"process": "ttbar", "cross_section": 831.8, "is_signal": False}
        ),
        "wjets": DatasetSpec(
            files={
                f"wjets_part{i}.root": "Events" for i in range(15)
            },
            metadata={"process": "wjets", "cross_section": 61526.7, "is_signal": False}
        )
    }
    
    # Data samples
    data_samples = {
        f"data_{era}": DatasetSpec(
            files={
                f"data_{era}_part{i}.root": "Events" for i in range(5)
            },
            metadata={"is_data": True, "era": era, "luminosity": 41.5}
        )
        for era in ["2022A", "2022B", "2022C", "2022D"]
    }
    
    # Combine all samples
    all_samples = {}
    all_samples.update(signal_samples)
    all_samples.update(background_samples)
    all_samples.update(data_samples)
    
    return FilesetSpec(all_samples)

# Build the fileset
full_analysis = build_analysis_fileset()
print(f"Full analysis fileset: {len(full_analysis)} datasets")

# Categorize datasets
signal_datasets = [name for name, ds in full_analysis.items() 
                  if ds.metadata.get("is_signal", False)]
background_datasets = [name for name, ds in full_analysis.items() 
                      if not ds.metadata.get("is_data", False) and not ds.metadata.get("is_signal", False)]
data_datasets = [name for name, ds in full_analysis.items() 
                if ds.metadata.get("is_data", False)]

print(f"Signal datasets: {len(signal_datasets)}")
print(f"Background datasets: {len(background_datasets)}")
print(f"Data datasets: {len(data_datasets)}")
# Out:
# === Complex Analysis Fileset ===
# Full analysis fileset: 9 datasets
# Signal datasets: 3
# Background datasets: 2
# Data datasets: 4

# %%
# 8.2 Conditional processing and dataset selection
print("=== Conditional Processing ===")

def select_datasets_by_criteria(fileset: FilesetSpec, **criteria) -> FilesetSpec:
    """Select datasets matching specific criteria"""
    selected = {}
    
    for name, dataset in fileset.items():
        match = True
        for key, value in criteria.items():
            if dataset.metadata.get(key) != value:
                match = False
                break
        
        if match:
            selected[name] = dataset
    
    return FilesetSpec(selected)

# Select only signal datasets
signal_only = select_datasets_by_criteria(full_analysis, is_signal=True)
print(f"Signal-only fileset: {len(signal_only)} datasets")

# Select 2022 data only
data_2022 = select_datasets_by_criteria(full_analysis, is_data=True)
data_2022_filtered = FilesetSpec({
    name: ds for name, ds in data_2022.items() 
    if "2022" in name
})
print(f"2022 data fileset: {len(data_2022_filtered)} datasets")

# Create a test subset with limited files
test_subset = FilesetSpec({
    name: max_files(FilesetSpec({name: ds}), maxfiles=2)[name]
    for name, ds in full_analysis.items()
    if name in signal_datasets[:2] + background_datasets[:1]
})
print(f"Test subset: {len(test_subset)} datasets with limited files")
# Out:
# === Conditional Processing ===
# Signal-only fileset: 3 datasets
# 2022 data fileset: 4 datasets
# Test subset: 3 datasets with limited files

# %%
# 8.3 Error handling and validation
print("=== Error Handling and Validation ===")

def validate_fileset(fileset: FilesetSpec) -> dict:
    """Validate a fileset and return diagnostic information"""
    diagnostics = {
        "total_datasets": len(fileset),
        "total_files": 0,
        "empty_datasets": [],
        "format_distribution": {},
        "metadata_issues": []
    }
    
    for name, dataset in fileset.items():
        # Count files
        num_files = len(dataset.files)
        diagnostics["total_files"] += num_files
        
        # Check for empty datasets
        if num_files == 0:
            diagnostics["empty_datasets"].append(name)
        
        # Track format distribution
        fmt = dataset.format
        diagnostics["format_distribution"][fmt] = diagnostics["format_distribution"].get(fmt, 0) + 1
        
        # Check metadata
        if not dataset.metadata:
            diagnostics["metadata_issues"].append(f"{name}: No metadata")
        elif "process" not in dataset.metadata and not dataset.metadata.get("is_data", False):
            diagnostics["metadata_issues"].append(f"{name}: Missing process information")
    
    return diagnostics

# Validate our analysis fileset
validation_results = validate_fileset(full_analysis)
print("Fileset validation results:")
for key, value in validation_results.items():
    if isinstance(value, list) and len(value) == 0:
        continue
    print(f"  {key}: {value}")
# Out:
# === Error Handling and Validation ===
# Fileset validation results:
#   total_datasets: 9
#   total_files: 54
#   format_distribution: {'root': 9}

# %%
# 8.4 Performance optimization strategies
print("=== Performance Optimization ===")

def optimize_fileset_for_processing(fileset: FilesetSpec, target_chunk_size: int = 100000) -> FilesetSpec:
    """Optimize fileset for processing performance"""
    
    optimized = {}
    
    for name, dataset in fileset.items():
        # Calculate total events and files
        total_events = sum(f.num_entries for f in dataset.files.values() 
                          if hasattr(f, 'num_entries') and f.num_entries)
        num_files = len(dataset.files)
        
        if total_events == 0:
            # Skip empty datasets
            continue
            
        # Determine optimal chunking strategy
        if total_events < target_chunk_size:
            # Small dataset - process as single chunk per file
            chunk_strategy = "single_chunk_per_file"
            optimized_dataset = dataset
        elif num_files < 5:
            # Few large files - use chunk slicing
            chunk_strategy = "chunk_slicing"
            max_chunks_total = max(1, total_events // target_chunk_size)
            optimized_dataset = max_chunks(FilesetSpec({name: dataset}), 
                                         maxchunks=max_chunks_total)[name]
        else:
            # Many files - limit files and chunks per file
            chunk_strategy = "file_and_chunk_limiting"
            max_files_count = min(num_files, 20)  # Limit to 20 files
            temp_fileset = max_files(FilesetSpec({name: dataset}), maxfiles=max_files_count)
            optimized_dataset = max_chunks_per_file(temp_fileset, maxchunks=5)[name]
        
        optimized[name] = optimized_dataset
        print(f"  {name}: {chunk_strategy}, {len(optimized_dataset.files)} files")
    
    return FilesetSpec(optimized)

# Optimize our test subset
optimized_subset = optimize_fileset_for_processing(test_subset)
print(f"Optimized subset: {len(optimized_subset)} datasets")
rich.print(optimized_subset)
# Out:
# === Performance Optimization ===
#   higgs_m125: chunk_slicing, 1 files
#   higgs_m200: chunk_slicing, 1 files
# Optimized subset: 2 datasets
# FilesetSpec(
#     root={
#         'higgs_m125': DatasetSpec(
#             files=InputFiles(
#                 root={
#                     'higgs_m125_part0.root': CoffeaROOTFileSpec(
#                         object_path='Events',
#                         steps=[[0, 5000], [5000, 10000]],
#                         num_entries=100000,
#                         format='root',
#                         uuid='higgs-125-0',
#                         num_selected_entries=10000
#                     )
#                 }
#             ),
#             metadata={'process': 'higgs', 'mass': 125, 'cross_section': 48.58, 'is_signal': True},
#             format='root',
#             compressed_form=None,
#             form=None
#         ),
#         'higgs_m200': DatasetSpec(
#             files=InputFiles(
#                 root={
#                     'higgs_m200_part0.root': CoffeaROOTFileSpec(
#                         object_path='Events',
#                         steps=[[0, 5000], [5000, 10000]],
#                         num_entries=100000,
#                         format='root',
#                         uuid='higgs-200-0',
#                         num_selected_entries=10000
#                     )
#                 }
#             ),
#             metadata={'process': 'higgs', 'mass': 200, 'cross_section': 10.0, 'is_signal': True},
#             format='root',
#             compressed_form=None,
#             form=None
#         )
#     }
# )

# %% [markdown]
# ## 9. Migration from pure dictionary Formats and conversion utility ModelFactory
#
# This section shows how to migrate from legacy dictionary-based filesets to the explicit FileSpec classes.
#
# Largely, a well-defined legacy fileset (purely nested dictionary) can be converted merely by passing it into the FilesetSpec as an argument.
#
# It should be noted that FilesetSpec, InputFiles, and PreprocessedFiles behave like dictionaries and expect a dictionary input, but the other filespec classes expect keyword arguments, and so when a dictionary is explicitly passed to the FileSpec constructors, they should be unpacked with the `**some_dict` syntax.

# %%
# 9.1 Legacy format examples
print("=== Legacy Format Migration ===")

# Legacy dictionary format (old style)
legacy_fileset = {
    "ttbar": {
        "files": {
            "ttbar_1.root": "Events",
            "ttbar_2.root": "Events"
        }
    },
    "data": {
        "files": {
            "data_1.root": {
                "object_path": "Events",
                "steps": [[0, 1000], [1000, 2000]],
                "num_entries": 2000,
                "uuid": "legacy-uuid"
            }
        }
    }
}

print("Legacy fileset structure:")
for name, content in legacy_fileset.items():
    print(f"  {name}: {len(content['files'])} files")
# Out:
# === Legacy Format Migration ===
# Legacy fileset structure:
#   ttbar: 2 files
#   data: 1 files

# %% [markdown]
# ## ModelFactory
#
# The `ModelFactory` class contains a few utility methods to help with manipulating the pydantic FileSpec classes. Largely, they serve as an example, with a few utilities regarding formats (which are called internally during validation/instantiation of the classes) plus conversion functions with simple logic for manipulating the filespec classes.
#
# - **dict_to_ROOTFileSpec**: Tries to convert the dictionary to a concrete CoffeaROOTFileSpec, and failing that, falls back to the Optional type
# - **dict_to_parquetfilespec**: Tries to convert the dictionary to a concrete CoffeaParquetFileSpec, and failing that, falls back to the Optional type
# - **filespec_to_dict**: Inverse function to convert FileSpec to dictionaries. Thanks to pydantic functionality, merely calls `.model_dump()` on the class
# - **dict_to_datasetspec**: Tries to convert the dictionary to a DatasetSpec, by utilizing the constructor.
# - **datasetspec_to_dict**: If coerce_filespec_to_dict is True (default), calls `.model_dump()` to completely convert to a dictionary. If False, only the outermost DatasetSpec is removed, leaving a dictionary of pydantic and elementary python types, which is the result of calling `dict(datasetspec)` instead of `.model_dump()`
# - **valid_format**: Ensures the format(s) are in the supported list for coffea processing
# - **attempt_promotion**: Will accept any of the FileSpec, DatasetSpec, or FilesetSpec and try to promote any(nested) types within to concrete classes. Can effectively be emulated by calling the pydantic class constructor on the output of the original model's `.model_dump()` method, with or without `**inputs` call in place (for non-dictionary-like models)

# %%
# 10.1 Converting formats
print("=== Converting legacy formats via ModelFactory ===")

print("The methods dict_to_ROOTFileSpec and dict_to_parquetfilespec are deprecated, as their functionality is covered by the pydantic models directly.")

print("For converting pydantic classes to dictionaries, the function datasetspec_to_dict demonstrates the two methods: model_dump() and dict(AModel).")
print("With the former, the entire model hierarchy is converted to dictionaries, while with the latter only the top-level model is converted, leaving nested models intact.")

pure_dictionary = ModelFactory.datasetspec_to_dict(full_analysis['ttbar'], coerce_filespec_to_dict=True)
print("DatasetSpec to pure dictionary (with coerce_filespec_to_dict=True):")
rich.print(pure_dictionary)

print("Accomplished via model_dump():")
rich.print(full_analysis['ttbar'].model_dump())

mixed_dictionary = ModelFactory.datasetspec_to_dict(full_analysis['ttbar'], coerce_filespec_to_dict=False)
print("DatasetSpec to top-level dictionary (with coerce_filespec_to_dict=False):")
rich.print(mixed_dictionary)

print("Now the partial conversion via dict():")
rich.print(dict(full_analysis['ttbar']))
# Out:
# === Converting legacy formats via ModelFactory ===
# The methods dict_to_ROOTFileSpec and dict_to_parquetfilespec are deprecated, as their functionality is covered by the pydantic models directly.
# For converting pydantic classes to dictionaries, the function datasetspec_to_dict demonstrates the two methods: model_dump() and dict(AModel).
# With the former, the entire model hierarchy is converted to dictionaries, while with the latter only the top-level model is converted, leaving nested models intact.
# DatasetSpec to pure dictionary (with coerce_filespec_to_dict=True):
# {
#     'files': {
#         'ttbar_part0.root': {
#             'object_path': 'Events',
#             'steps': None,
#             'num_entries': None,
#             'format': 'root',
#             'uuid': None,
#             'num_selected_entries': None
#         },
#         'ttbar_part1.root': {
#             'object_path': 'Events',
#             'steps': None,
#             'num_entries': None,
#             'format': 'root',
#             'uuid': None,
#             'num_selected_entries': None
#         },
#         'ttbar_part2.root': {
#             'object_path': 'Events',
#             'steps': None,
#             'num_entries': None,
#             'format': 'root',
#             'uuid': None,
#             'num_selected_entries': None
#         },
#         'ttbar_part3.root': {
#             'object_path': 'Events',
#             'steps': None,
#             'num_entries': None,
#             'format': 'root',
#             'uuid': None,
#             'num_selected_entries': None
#         },
#         'ttbar_part4.root': {
#             'object_path': 'Events',
#             'steps': None,
#             'num_entries': None,
#             'format': 'root',
#             'uuid': None,
#             'num_selected_entries': None
#         },
#         'ttbar_part5.root': {
#             'object_path': 'Events',
#             'steps': None,
#             'num_entries': None,
#             'format': 'root',
#             'uuid': None,
#             'num_selected_entries': None
#         },
#         'ttbar_part6.root': {
#             'object_path': 'Events',
#             'steps': None,
#             'num_entries': None,
#             'format': 'root',
#             'uuid': None,
#             'num_selected_entries': None
#         },
#         'ttbar_part7.root': {
#             'object_path': 'Events',
#             'steps': None,
#             'num_entries': None,
#             'format': 'root',
#             'uuid': None,
#             'num_selected_entries': None
#         },
#         'ttbar_part8.root': {
#             'object_path': 'Events',
#             'steps': None,
#             'num_entries': None,
#             'format': 'root',
#             'uuid': None,
#             'num_selected_entries': None
#         },
#         'ttbar_part9.root': {
#             'object_path': 'Events',
#             'steps': None,
#             'num_entries': None,
#             'format': 'root',
#             'uuid': None,
#             'num_selected_entries': None
#         }
#     },
#     'metadata': {'process': 'ttbar', 'cross_section': 831.8, 'is_signal': False},
#     'format': 'root',
#     'compressed_form': None,
#     'form': None
# }
# Accomplished via model_dump():
# {
#     'files': {
#         'ttbar_part0.root': {
#             'object_path': 'Events',
#             'steps': None,
#             'num_entries': None,
#             'format': 'root',
#             'uuid': None,
#             'num_selected_entries': None
#         },
#         'ttbar_part1.root': {
#             'object_path': 'Events',
#             'steps': None,
#             'num_entries': None,
#             'format': 'root',
#             'uuid': None,
#             'num_selected_entries': None
#         },
#         'ttbar_part2.root': {
#             'object_path': 'Events',
#             'steps': None,
#             'num_entries': None,
#             'format': 'root',
#             'uuid': None,
#             'num_selected_entries': None
#         },
#         'ttbar_part3.root': {
#             'object_path': 'Events',
#             'steps': None,
#             'num_entries': None,
#             'format': 'root',
#             'uuid': None,
#             'num_selected_entries': None
#         },
#         'ttbar_part4.root': {
#             'object_path': 'Events',
#             'steps': None,
#             'num_entries': None,
#             'format': 'root',
#             'uuid': None,
#             'num_selected_entries': None
#         },
#         'ttbar_part5.root': {
#             'object_path': 'Events',
#             'steps': None,
#             'num_entries': None,
#             'format': 'root',
#             'uuid': None,
#             'num_selected_entries': None
#         },
#         'ttbar_part6.root': {
#             'object_path': 'Events',
#             'steps': None,
#             'num_entries': None,
#             'format': 'root',
#             'uuid': None,
#             'num_selected_entries': None
#         },
#         'ttbar_part7.root': {
#             'object_path': 'Events',
#             'steps': None,
#             'num_entries': None,
#             'format': 'root',
#             'uuid': None,
#             'num_selected_entries': None
#         },
#         'ttbar_part8.root': {
#             'object_path': 'Events',
#             'steps': None,
#             'num_entries': None,
#             'format': 'root',
#             'uuid': None,
#             'num_selected_entries': None
#         },
#         'ttbar_part9.root': {
#             'object_path': 'Events',
#             'steps': None,
#             'num_entries': None,
#             'format': 'root',
#             'uuid': None,
#             'num_selected_entries': None
#         }
#     },
#     'metadata': {'process': 'ttbar', 'cross_section': 831.8, 'is_signal': False},
#     'format': 'root',
#     'compressed_form': None,
#     'form': None
# }
# DatasetSpec to top-level dictionary (with coerce_filespec_to_dict=False):
# {
#     'files': InputFiles(
#         root={
#             'ttbar_part0.root': CoffeaROOTFileSpecOptional(
#                 object_path='Events',
#                 steps=None,
#                 num_entries=None,
#                 format='root',
#                 uuid=None,
#                 num_selected_entries=None
#             ),
#             'ttbar_part1.root': CoffeaROOTFileSpecOptional(
#                 object_path='Events',
#                 steps=None,
#                 num_entries=None,
#                 format='root',
#                 uuid=None,
#                 num_selected_entries=None
#             ),
#             'ttbar_part2.root': CoffeaROOTFileSpecOptional(
#                 object_path='Events',
#                 steps=None,
#                 num_entries=None,
#                 format='root',
#                 uuid=None,
#                 num_selected_entries=None
#             ),
#             'ttbar_part3.root': CoffeaROOTFileSpecOptional(
#                 object_path='Events',
#                 steps=None,
#                 num_entries=None,
#                 format='root',
#                 uuid=None,
#                 num_selected_entries=None
#             ),
#             'ttbar_part4.root': CoffeaROOTFileSpecOptional(
#                 object_path='Events',
#                 steps=None,
#                 num_entries=None,
#                 format='root',
#                 uuid=None,
#                 num_selected_entries=None
#             ),
#             'ttbar_part5.root': CoffeaROOTFileSpecOptional(
#                 object_path='Events',
#                 steps=None,
#                 num_entries=None,
#                 format='root',
#                 uuid=None,
#                 num_selected_entries=None
#             ),
#             'ttbar_part6.root': CoffeaROOTFileSpecOptional(
#                 object_path='Events',
#                 steps=None,
#                 num_entries=None,
#                 format='root',
#                 uuid=None,
#                 num_selected_entries=None
#             ),
#             'ttbar_part7.root': CoffeaROOTFileSpecOptional(
#                 object_path='Events',
#                 steps=None,
#                 num_entries=None,
#                 format='root',
#                 uuid=None,
#                 num_selected_entries=None
#             ),
#             'ttbar_part8.root': CoffeaROOTFileSpecOptional(
#                 object_path='Events',
#                 steps=None,
#                 num_entries=None,
#                 format='root',
#                 uuid=None,
#                 num_selected_entries=None
#             ),
#             'ttbar_part9.root': CoffeaROOTFileSpecOptional(
#                 object_path='Events',
#                 steps=None,
#                 num_entries=None,
#                 format='root',
#                 uuid=None,
#                 num_selected_entries=None
#             )
#         }
#     ),
#     'metadata': {'process': 'ttbar', 'cross_section': 831.8, 'is_signal': False},
#     'format': 'root',
#     'compressed_form': None
# }
# Now the partial conversion via dict():
# {
#     'files': InputFiles(
#         root={
#             'ttbar_part0.root': CoffeaROOTFileSpecOptional(
#                 object_path='Events',
#                 steps=None,
#                 num_entries=None,
#                 format='root',
#                 uuid=None,
#                 num_selected_entries=None
#             ),
#             'ttbar_part1.root': CoffeaROOTFileSpecOptional(
#                 object_path='Events',
#                 steps=None,
#                 num_entries=None,
#                 format='root',
#                 uuid=None,
#                 num_selected_entries=None
#             ),
#             'ttbar_part2.root': CoffeaROOTFileSpecOptional(
#                 object_path='Events',
#                 steps=None,
#                 num_entries=None,
#                 format='root',
#                 uuid=None,
#                 num_selected_entries=None
#             ),
#             'ttbar_part3.root': CoffeaROOTFileSpecOptional(
#                 object_path='Events',
#                 steps=None,
#                 num_entries=None,
#                 format='root',
#                 uuid=None,
#                 num_selected_entries=None
#             ),
#             'ttbar_part4.root': CoffeaROOTFileSpecOptional(
#                 object_path='Events',
#                 steps=None,
#                 num_entries=None,
#                 format='root',
#                 uuid=None,
#                 num_selected_entries=None
#             ),
#             'ttbar_part5.root': CoffeaROOTFileSpecOptional(
#                 object_path='Events',
#                 steps=None,
#                 num_entries=None,
#                 format='root',
#                 uuid=None,
#                 num_selected_entries=None
#             ),
#             'ttbar_part6.root': CoffeaROOTFileSpecOptional(
#                 object_path='Events',
#                 steps=None,
#                 num_entries=None,
#                 format='root',
#                 uuid=None,
#                 num_selected_entries=None
#             ),
#             'ttbar_part7.root': CoffeaROOTFileSpecOptional(
#                 object_path='Events',
#                 steps=None,
#                 num_entries=None,
#                 format='root',
#                 uuid=None,
#                 num_selected_entries=None
#             ),
#             'ttbar_part8.root': CoffeaROOTFileSpecOptional(
#                 object_path='Events',
#                 steps=None,
#                 num_entries=None,
#                 format='root',
#                 uuid=None,
#                 num_selected_entries=None
#             ),
#             'ttbar_part9.root': CoffeaROOTFileSpecOptional(
#                 object_path='Events',
#                 steps=None,
#                 num_entries=None,
#                 format='root',
#                 uuid=None,
#                 num_selected_entries=None
#             )
#         }
#     ),
#     'metadata': {'process': 'ttbar', 'cross_section': 831.8, 'is_signal': False},
#     'format': 'root',
#     'compressed_form': None
# }

# %%
# 10.2 valid_format checks
print("=== Valid Format Checks ===")

print("Does full_analysis['ttbar'] have a valid format?\n\t", ModelFactory.valid_format(full_analysis['ttbar']))
print("What is the format?\n\t", full_analysis['ttbar'].format)
print("Does a mixed-format dataset have a valid format?\n\t", ModelFactory.valid_format(mixed_dataset))
print("What is the format?\n\t", mixed_dataset.format)
# Out:
# === Valid Format Checks ===
# Does full_analysis['ttbar'] have a valid format?
# 	 True
# What is the format?
# 	 root
# Does a mixed-format dataset have a valid format?
# 	 True
# What is the format?
# 	 root|parquet

# %%
# 10.3 Promoting Specs to concrete types
print("=== Promoting Specs to Concrete Types ===")
print("ModelFactory.attempt_promotion can be used to update Spcs after parameters have been set, fulfilling the requirements of the non-Optional variants.")
starting_spec = CoffeaROOTFileSpecOptional(object_path="Events", steps=[[0, 1000]])
print("Starting with CoffeaROOTFileSpecOptional:")
rich.print(starting_spec)
starting_spec.num_entries = 1000
starting_spec.uuid = "promote-me"
print("After setting num_entries and uuid:")
rich.print(starting_spec)
promoted_spec = ModelFactory.attempt_promotion(starting_spec)
print("After promotion to CoffeaROOTFileSpec:")
rich.print(promoted_spec)
# Out:
# === Promoting Specs to Concrete Types ===
# ModelFactory.attempt_promotion can be used to update Spcs after parameters have been set, fulfilling the requirements of the non-Optional variants.
# Starting with CoffeaROOTFileSpecOptional:
# CoffeaROOTFileSpecOptional(
#     object_path='Events',
#     steps=[[0, 1000]],
#     num_entries=None,
#     format='root',
#     uuid=None,
#     num_selected_entries=1000
# )
# After setting num_entries and uuid:
# CoffeaROOTFileSpecOptional(
#     object_path='Events',
#     steps=[[0, 1000]],
#     num_entries=1000,
#     format='root',
#     uuid='promote-me',
#     num_selected_entries=1000
# )
# After promotion to CoffeaROOTFileSpec:
# CoffeaROOTFileSpec(
#     object_path='Events',
#     steps=[[0, 1000]],
#     num_entries=1000,
#     format='root',
#     uuid='promote-me',
#     num_selected_entries=1000
# )
